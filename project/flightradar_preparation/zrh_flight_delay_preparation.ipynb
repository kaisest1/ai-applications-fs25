# %% [markdown]
# # Data preparation
# ## Read and show Excel data for one day from Flightradar

# %%
import pandas as pd

# %%
# XLSX-Datei laden
flightradar = pd.read_excel("250502_flightradar.xlsx")

# Erste 5 Zeilen anzeigen
print(flightradar.head(5))
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746256881-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746256881-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746256881-3  https://www.flightradar24.com/data/airports/zr...   NaN
# 3      1746256881-4  https://www.flightradar24.com/data/airports/zr...   NaN
# 4      1746256881-5  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  FLIGHT  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   WK186
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22160
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   CS600
# 3    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK130
# 4    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK226
#
#        DESTINATION           AIRLINE       AIRCRAFT          STATUS
# 0   Antalya (AYT)-   Edelweiss Air -  A359 (HB-IHF)  Departed 06:07
# 1  Pristina (PRN)-      Flexflight -         320 ()         Unknown
# 2  Pristina (PRN)-  Chair Airlines -  A320 (HB-JOS)  Departed 06:11
# 3  Hurghada (HRG)-   Edelweiss Air -  A320 (HB-JJN)  Departed 06:13
# 4    Bilbao (BIO)-   Edelweiss Air -  A320 (HB-IHY)  Departed 06:28

# %% [markdown]
# ## Show data types and shape of the DataFrame

# %%
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# dtype: object
# (383, 15)

# %% [markdown]
# ## The Date is missing in the DataFrame. Create a new field DATETIME
# ### DATETIME is the planned departure time for that day

# %%
# Datum als Variable definieren
date_str = "2025-05-02"

# %%
# TIME als String sicherstellen (falls es z. B. float ist)
flightradar["TIME"] = flightradar["TIME"].astype(str)

# DATETIME-Feld erzeugen: 'date_str' + Zeit aus TIME-Feld
flightradar["DATETIME"] = date_str + " " + flightradar["TIME"]

# Kontrolle
print(flightradar[["TIME", "DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#         TIME             DATETIME
# 0   05:45:00  2025-05-02 05:45:00
# 1   05:45:00  2025-05-02 05:45:00
# 2   05:45:00  2025-05-02 05:45:00
# 3   06:00:00  2025-05-02 06:00:00
# 4   06:00:00  2025-05-02 06:00:00
# 5   06:10:00  2025-05-02 06:10:00
# 6   06:10:00  2025-05-02 06:10:00
# 7   06:20:00  2025-05-02 06:20:00
# 8   06:20:00  2025-05-02 06:20:00
# 9   06:20:00  2025-05-02 06:20:00
# 10  06:25:00  2025-05-02 06:25:00
# 11  06:25:00  2025-05-02 06:25:00
# 12  06:25:00  2025-05-02 06:25:00
# 13  06:30:00  2025-05-02 06:30:00
# 14  06:30:00  2025-05-02 06:30:00
# 15  06:30:00  2025-05-02 06:30:00
# 16  06:30:00  2025-05-02 06:30:00
# 17  06:35:00  2025-05-02 06:35:00
# 18  06:45:00  2025-05-02 06:45:00
# 19  06:45:00  2025-05-02 06:45:00
# 20  06:50:00  2025-05-02 06:50:00
# 21  06:50:00  2025-05-02 06:50:00
# 22  06:55:00  2025-05-02 06:55:00
# 23  06:55:00  2025-05-02 06:55:00
# 24  06:55:00  2025-05-02 06:55:00
# 25  06:55:00  2025-05-02 06:55:00
# 26  06:55:00  2025-05-02 06:55:00
# 27  07:00:00  2025-05-02 07:00:00
# 28  07:00:00  2025-05-02 07:00:00
# 29  07:00:00  2025-05-02 07:00:00
# 30  07:00:00  2025-05-02 07:00:00
# 31  07:05:00  2025-05-02 07:05:00
# 32  07:05:00  2025-05-02 07:05:00
# 33  07:05:00  2025-05-02 07:05:00
# 34  07:10:00  2025-05-02 07:10:00
# 35  07:10:00  2025-05-02 07:10:00
# 36  07:10:00  2025-05-02 07:10:00
# 37  07:15:00  2025-05-02 07:15:00
# 38  07:15:00  2025-05-02 07:15:00
# 39  07:15:00  2025-05-02 07:15:00
# 40  07:15:00  2025-05-02 07:15:00
# 41  07:20:00  2025-05-02 07:20:00
# 42  07:20:00  2025-05-02 07:20:00
# 43  07:20:00  2025-05-02 07:20:00
# 44  07:20:00  2025-05-02 07:20:00
# 45  07:25:00  2025-05-02 07:25:00
# 46  07:25:00  2025-05-02 07:25:00
# 47  07:25:00  2025-05-02 07:25:00
# 48  07:30:00  2025-05-02 07:30:00
# 49  07:30:00  2025-05-02 07:30:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# dtype: object
# (383, 16)

# %% [markdown]
# ## Create two new fields: DESTINATION_CLEAN and IATA_CODE using regex

# %%
# DESTINATION_CLEAN: Alles vor der Klammer
flightradar["DESTINATION_CLEAN"] = flightradar["DESTINATION"].str.extract(r"^(.*?)\s*\(")

# IATA-CODE: Inhalt in der Klammer
flightradar["IATA_CODE"] = flightradar["DESTINATION"].str.extract(r"\((\w{3})\)")

# Kontrolle
print(flightradar[["DESTINATION", "DESTINATION_CLEAN", "IATA_CODE"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                  DESTINATION  DESTINATION_CLEAN IATA_CODE
# 0             Antalya (AYT)-            Antalya       AYT
# 1            Pristina (PRN)-           Pristina       PRN
# 2            Pristina (PRN)-           Pristina       PRN
# 3            Hurghada (HRG)-           Hurghada       HRG
# 4              Bilbao (BIO)-             Bilbao       BIO
# 5              Lisbon (LIS)-             Lisbon       LIS
# 6            Pristina (PRN)-           Pristina       PRN
# 7               Porto (OPO)-              Porto       OPO
# 8     Sharm el-Sheikh (SSH)-    Sharm el-Sheikh       SSH
# 9             Seville (SVQ)-            Seville       SVQ
# 10       Gran Canaria (LPA)-       Gran Canaria       LPA
# 11            Funchal (FNC)-            Funchal       FNC
# 12            Larnaca (LCA)-            Larnaca       LCA
# 13             Dublin (DUB)-             Dublin       DUB
# 14           Tenerife (TFS)-           Tenerife       TFS
# 15           Hurghada (HRG)-           Hurghada       HRG
# 16           Hurghada (HRG)-           Hurghada       HRG
# 17          Edinburgh (EDI)-          Edinburgh       EDI
# 18  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 19           Hurghada (HRG)-           Hurghada       HRG
# 20         Birmingham (BHX)-         Birmingham       BHX
# 21             Gdansk (GDN)-             Gdansk       GDN
# 22          Frankfurt (FRA)-          Frankfurt       FRA
# 23           Belgrade (BEG)-           Belgrade       BEG
# 24             Kosice (KSC)-             Kosice       KSC
# 25             Madrid (MAD)-             Madrid       MAD
# 26           Belgrade (BEG)-           Belgrade       BEG
# 27          Amsterdam (AMS)-          Amsterdam       AMS
# 28             Tirana (TIA)-             Tirana       TIA
# 29             Naples (NAP)-             Naples       NAP
# 30            Palermo (PMO)-            Palermo       PMO
# 31             London (LHR)-             London       LHR
# 32             Warsaw (WAW)-             Warsaw       WAW
# 33         Manchester (MAN)-         Manchester       MAN
# 34         Copenhagen (CPH)-         Copenhagen       CPH
# 35          Barcelona (BCN)-          Barcelona       BCN
# 36           Budapest (BUD)-           Budapest       BUD
# 37             London (LHR)-             London       LHR
# 38            Hamburg (HAM)-            Hamburg       HAM
# 39             Munich (MUC)-             Munich       MUC
# 40             Krakow (KRK)-             Krakow       KRK
# 41             Berlin (BER)-             Berlin       BER
# 42          Amsterdam (AMS)-          Amsterdam       AMS
# 43             Vienna (VIE)-             Vienna       VIE
# 44               Rome (FCO)-               Rome       FCO
# 45              Paris (CDG)-              Paris       CDG
# 46           Brussels (BRU)-           Brussels       BRU
# 47             Geneva (GVA)-             Geneva       GVA
# 48             Madrid (MAD)-             Madrid       MAD
# 49               Nice (NCE)-               Nice       NCE
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# dtype: object
# (383, 18)

# %% [markdown]
# ## Create three new fields: CANCELED, DEPART_TIME and DEPART_DATETIME using regex

# %%
# 1. CANCELED-Spalte (Boolean)
flightradar["CANCELED"] = flightradar["STATUS"].str.contains("Canceled", na=False)

# 2. DEPART_TIME-Spalte (nur wenn "Departed HH:MM" enthalten ist)
flightradar["DEPART_TIME"] = flightradar["STATUS"].str.extract(r"Departed\s*(\d{2}:\d{2})")[0]

# 3. DEPART_DATETIME-Spalte: date_str + DEPART_TIME (fallback "00:00") + ":00"
flightradar["DEPART_DATETIME"] = (
    date_str
    + " "
    + flightradar["DEPART_TIME"].fillna("00:00") # falls keine Zeit da ist, setze "00:00"
    + ":00" # Sekunden anhängen
)

# Kontrolle
print(flightradar[["STATUS","CANCELED","DEPART_TIME","DEPART_DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                    STATUS  CANCELED DEPART_TIME      DEPART_DATETIME
# 0          Departed 06:07     False       06:07  2025-05-02 06:07:00
# 1                 Unknown     False         NaN  2025-05-02 00:00:00
# 2          Departed 06:11     False       06:11  2025-05-02 06:11:00
# 3          Departed 06:13     False       06:13  2025-05-02 06:13:00
# 4          Departed 06:28     False       06:28  2025-05-02 06:28:00
# 5          Departed 06:41     False       06:41  2025-05-02 06:41:00
# 6          Departed 06:50     False       06:50  2025-05-02 06:50:00
# 7          Departed 06:52     False       06:52  2025-05-02 06:52:00
# 8          Departed 06:30     False       06:30  2025-05-02 06:30:00
# 9          Departed 06:35     False       06:35  2025-05-02 06:35:00
# 10         Departed 07:01     False       07:01  2025-05-02 07:01:00
# 11         Departed 06:56     False       06:56  2025-05-02 06:56:00
# 12         Departed 06:55     False       06:55  2025-05-02 06:55:00
# 13         Departed 06:38     False       06:38  2025-05-02 06:38:00
# 14         Departed 07:11     False       07:11  2025-05-02 07:11:00
# 15                Unknown     False         NaN  2025-05-02 00:00:00
# 16         Departed 06:44     False       06:44  2025-05-02 06:44:00
# 17         Departed 06:42     False       06:42  2025-05-02 06:42:00
# 18         Departed 06:58     False       06:58  2025-05-02 06:58:00
# 19         Departed 07:05     False       07:05  2025-05-02 07:05:00
# 20         Departed 07:10     False       07:10  2025-05-02 07:10:00
# 21         Departed 07:06     False       07:06  2025-05-02 07:06:00
# 22         Departed 07:08     False       07:08  2025-05-02 07:08:00
# 23  Estimated dep.  07:11     False         NaN  2025-05-02 00:00:00
# 24         Departed 07:13     False       07:13  2025-05-02 07:13:00
# 25         Departed 07:35     False       07:35  2025-05-02 07:35:00
# 26         Departed 07:16     False       07:16  2025-05-02 07:16:00
# 27         Departed 07:23     False       07:23  2025-05-02 07:23:00
# 28         Departed 07:21     False       07:21  2025-05-02 07:21:00
# 29         Departed 07:18     False       07:18  2025-05-02 07:18:00
# 30         Departed 07:14     False       07:14  2025-05-02 07:14:00
# 31         Departed 07:27     False       07:27  2025-05-02 07:27:00
# 32         Departed 07:19     False       07:19  2025-05-02 07:19:00
# 33         Departed 08:48     False       08:48  2025-05-02 08:48:00
# 34         Departed 07:25     False       07:25  2025-05-02 07:25:00
# 35         Departed 07:37     False       07:37  2025-05-02 07:37:00
# 36         Departed 07:28     False       07:28  2025-05-02 07:28:00
# 37         Departed 07:32     False       07:32  2025-05-02 07:32:00
# 38         Departed 07:30     False       07:30  2025-05-02 07:30:00
# 39         Departed 07:33     False       07:33  2025-05-02 07:33:00
# 40         Departed 07:38     False       07:38  2025-05-02 07:38:00
# 41         Departed 07:41     False       07:41  2025-05-02 07:41:00
# 42         Departed 07:59     False       07:59  2025-05-02 07:59:00
# 43         Departed 07:44     False       07:44  2025-05-02 07:44:00
# 44         Departed 07:40     False       07:40  2025-05-02 07:40:00
# 45         Departed 07:46     False       07:46  2025-05-02 07:46:00
# 46         Departed 07:43     False       07:43  2025-05-02 07:43:00
# 47         Departed 07:53     False       07:53  2025-05-02 07:53:00
# 48         Departed 07:49     False       07:49  2025-05-02 07:49:00
# 49         Departed 07:56     False       07:56  2025-05-02 07:56:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# dtype: object
# (383, 21)

# %% [markdown]
# ## Creating the AIRLINE_CLEAN field and removing unimportant parts

# %%
flightradar["AIRLINE_CLEAN"] = (
    flightradar["AIRLINE"]
      .str.extract(r'^(.+?)(?=\s*(?:\(|-))')[0]  # Gruppe 1: alles bis vor "(" oder "-"
      .str.strip()                               # führende/trailing Leerzeichen entfernen
)

# Kontrolle
print(flightradar[["AIRLINE","AIRLINE_CLEAN"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                                    AIRLINE     AIRLINE_CLEAN
# 0                          Edelweiss Air -     Edelweiss Air
# 1                             Flexflight -        Flexflight
# 2                         Chair Airlines -    Chair Airlines
# 3                          Edelweiss Air -     Edelweiss Air
# 4                          Edelweiss Air -     Edelweiss Air
# 5                       TAP Air Portugal -  TAP Air Portugal
# 6                          Edelweiss Air -     Edelweiss Air
# 7                                  Swiss -             Swiss
# 8                          Edelweiss Air -     Edelweiss Air
# 9                          Edelweiss Air -     Edelweiss Air
# 10                         Edelweiss Air -     Edelweiss Air
# 11                         Edelweiss Air -     Edelweiss Air
# 12                         Edelweiss Air -     Edelweiss Air
# 13                      Helvetic Airways -  Helvetic Airways
# 14                         Edelweiss Air -     Edelweiss Air
# 15                            Flexflight -        Flexflight
# 16                        Chair Airlines -    Chair Airlines
# 17                         Edelweiss Air -     Edelweiss Air
# 18                                 Swiss -             Swiss
# 19                         Edelweiss Air -     Edelweiss Air
# 20                                 Swiss -             Swiss
# 21                      Helvetic Airways -  Helvetic Airways
# 22                      Helvetic Airways -  Helvetic Airways
# 23                                 Swiss -             Swiss
# 24                            Air Baltic -        Air Baltic
# 25                      Helvetic Airways -  Helvetic Airways
# 26                                 Swiss -             Swiss
# 27                                   KLM -               KLM
# 28                      Helvetic Airways -  Helvetic Airways
# 29                                 Swiss -             Swiss
# 30                                 Swiss -             Swiss
# 31                                 Swiss -             Swiss
# 32                      Helvetic Airways -  Helvetic Airways
# 33                                 Swiss -             Swiss
# 34                                 Swiss -             Swiss
# 35                                 Swiss -             Swiss
# 36                            Air Baltic -        Air Baltic
# 37                       British Airways -   British Airways
# 38                      Helvetic Airways -  Helvetic Airways
# 39  Edelweiss Air (Help Alliance Livery) -     Edelweiss Air
# 40                      Helvetic Airways -  Helvetic Airways
# 41                                 Swiss -             Swiss
# 42                                 Swiss -             Swiss
# 43          Swiss (Star Alliance Livery) -             Swiss
# 44          Swiss (Star Alliance Livery) -             Swiss
# 45                                 Swiss -             Swiss
# 46                                 Swiss -             Swiss
# 47                                 Swiss -             Swiss
# 48                                Iberia -            Iberia
# 49                                 Swiss -             Swiss
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# dtype: object
# (383, 22)

# %% [markdown]
# ## Creating the AIRCRAFT_SHORT field

# %%
# Create the AIRCRAFT_SHORT field by removing text inside parentheses
flightradar["AIRCRAFT_SHORT"] = (
    flightradar["AIRCRAFT"]
      .str.replace(r"\s*\(.*?\)", "", regex=True)  # non‑greedy, regex=True
      .str.strip()
)

# Check the result
print(flightradar[["AIRCRAFT", "AIRCRAFT_SHORT"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#          AIRCRAFT AIRCRAFT_SHORT
# 0   A359 (HB-IHF)           A359
# 1          320 ()            320
# 2   A320 (HB-JOS)           A320
# 3   A320 (HB-JJN)           A320
# 4   A320 (HB-IHY)           A320
# 5   A20N (CS-TVO)           A20N
# 6   A320 (HB-IJW)           A320
# 7   BCS3 (HB-JCU)           BCS3
# 8   A320 (HB-JLR)           A320
# 9   A320 (HB-IHZ)           A320
# 10  A320 (HB-JJM)           A320
# 11  A320 (HB-JLS)           A320
# 12  A320 (HB-IHX)           A320
# 13  E290 (HB-AZG)           E290
# 14  A320 (HB-IJU)           A320
# 15         320 ()            320
# 16  A320 (HB-JOK)           A320
# 17  A320 (HB-IJV)           A320
# 18  A321 (HB-ION)           A321
# 19  A320 (HB-JLP)           A320
# 20  BCS3 (HB-JCB)           BCS3
# 21  E190 (HB-JVM)           E190
# 22  E190 (HB-JVX)           E190
# 23  BCS3 (HB-JCF)           BCS3
# 24  BCS3 (YL-AAW)           BCS3
# 25  E295 (HB-AZI)           E295
# 26  BCS3 (HB-JCF)           BCS3
# 27  B738 (PH-BXY)           B738
# 28  E290 (HB-AZC)           E290
# 29  A320 (HB-IJR)           A320
# 30  A20N (HB-JDA)           A20N
# 31  A21N (HB-JPA)           A21N
# 32  E190 (HB-JVO)           E190
# 33  BCS3 (HB-JCO)           BCS3
# 34  A320 (HB-IJK)           A320
# 35  A321 (HB-IOO)           A321
# 36  BCS3 (YL-CSH)           BCS3
# 37  A20N (G-TTNP)           A20N
# 38  E295 (HB-AZK)           E295
# 39  A320 (HB-JLT)           A320
# 40  E195 (HB-JVZ)           E195
# 41  BCS1 (HB-JBE)           BCS1
# 42  A20N (HB-JDE)           A20N
# 43  A320 (HB-IJM)           A320
# 44  A320 (HB-IJO)           A320
# 45  A320 (HB-IJP)           A320
# 46  A320 (HB-IJI)           A320
# 47  A321 (HB-IOH)           A321
# 48  A20N (EC-NCM)           A20N
# 49  BCS3 (HB-JCK)           BCS3
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# AIRCRAFT_SHORT            object
# dtype: object
# (383, 23)

# %% [markdown]
# ## Create a new field DELAY and DELAY_MINUTES and calculate it from DATETIME and DEPART_DATETIME

# %%
# 1) Stelle sicher, dass beide Spalten als datetime64 vorliegen
flightradar["DATETIME"] = pd.to_datetime(flightradar["DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
flightradar["DEPART_DATETIME"] = pd.to_datetime(flightradar["DEPART_DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")

# 2) DELAY als Differenz berechnen
flightradar["DELAY"] = flightradar["DEPART_DATETIME"] - flightradar["DATETIME"]

# 3a) Variante A: Floor‑Division auf total_seconds, dann in int
flightradar["DELAY_MINUTES"] = (
    flightradar["DELAY"].dt.total_seconds() // 60
).astype(int)

# Kontrolle
print(flightradar[["DATETIME","DEPART_DATETIME","DELAY","DELAY_MINUTES"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#               DATETIME     DEPART_DATETIME             DELAY  DELAY_MINUTES
# 0  2025-05-02 05:45:00 2025-05-02 06:07:00   0 days 00:22:00             22
# 1  2025-05-02 05:45:00 2025-05-02 00:00:00 -1 days +18:15:00           -345
# 2  2025-05-02 05:45:00 2025-05-02 06:11:00   0 days 00:26:00             26
# 3  2025-05-02 06:00:00 2025-05-02 06:13:00   0 days 00:13:00             13
# 4  2025-05-02 06:00:00 2025-05-02 06:28:00   0 days 00:28:00             28
# 5  2025-05-02 06:10:00 2025-05-02 06:41:00   0 days 00:31:00             31
# 6  2025-05-02 06:10:00 2025-05-02 06:50:00   0 days 00:40:00             40
# 7  2025-05-02 06:20:00 2025-05-02 06:52:00   0 days 00:32:00             32
# 8  2025-05-02 06:20:00 2025-05-02 06:30:00   0 days 00:10:00             10
# 9  2025-05-02 06:20:00 2025-05-02 06:35:00   0 days 00:15:00             15
# 10 2025-05-02 06:25:00 2025-05-02 07:01:00   0 days 00:36:00             36
# 11 2025-05-02 06:25:00 2025-05-02 06:56:00   0 days 00:31:00             31
# 12 2025-05-02 06:25:00 2025-05-02 06:55:00   0 days 00:30:00             30
# 13 2025-05-02 06:30:00 2025-05-02 06:38:00   0 days 00:08:00              8
# 14 2025-05-02 06:30:00 2025-05-02 07:11:00   0 days 00:41:00             41
# 15 2025-05-02 06:30:00 2025-05-02 00:00:00 -1 days +17:30:00           -390
# 16 2025-05-02 06:30:00 2025-05-02 06:44:00   0 days 00:14:00             14
# 17 2025-05-02 06:35:00 2025-05-02 06:42:00   0 days 00:07:00              7
# 18 2025-05-02 06:45:00 2025-05-02 06:58:00   0 days 00:13:00             13
# 19 2025-05-02 06:45:00 2025-05-02 07:05:00   0 days 00:20:00             20
# 20 2025-05-02 06:50:00 2025-05-02 07:10:00   0 days 00:20:00             20
# 21 2025-05-02 06:50:00 2025-05-02 07:06:00   0 days 00:16:00             16
# 22 2025-05-02 06:55:00 2025-05-02 07:08:00   0 days 00:13:00             13
# 23 2025-05-02 06:55:00 2025-05-02 00:00:00 -1 days +17:05:00           -415
# 24 2025-05-02 06:55:00 2025-05-02 07:13:00   0 days 00:18:00             18
# 25 2025-05-02 06:55:00 2025-05-02 07:35:00   0 days 00:40:00             40
# 26 2025-05-02 06:55:00 2025-05-02 07:16:00   0 days 00:21:00             21
# 27 2025-05-02 07:00:00 2025-05-02 07:23:00   0 days 00:23:00             23
# 28 2025-05-02 07:00:00 2025-05-02 07:21:00   0 days 00:21:00             21
# 29 2025-05-02 07:00:00 2025-05-02 07:18:00   0 days 00:18:00             18
# 30 2025-05-02 07:00:00 2025-05-02 07:14:00   0 days 00:14:00             14
# 31 2025-05-02 07:05:00 2025-05-02 07:27:00   0 days 00:22:00             22
# 32 2025-05-02 07:05:00 2025-05-02 07:19:00   0 days 00:14:00             14
# 33 2025-05-02 07:05:00 2025-05-02 08:48:00   0 days 01:43:00            103
# 34 2025-05-02 07:10:00 2025-05-02 07:25:00   0 days 00:15:00             15
# 35 2025-05-02 07:10:00 2025-05-02 07:37:00   0 days 00:27:00             27
# 36 2025-05-02 07:10:00 2025-05-02 07:28:00   0 days 00:18:00             18
# 37 2025-05-02 07:15:00 2025-05-02 07:32:00   0 days 00:17:00             17
# 38 2025-05-02 07:15:00 2025-05-02 07:30:00   0 days 00:15:00             15
# 39 2025-05-02 07:15:00 2025-05-02 07:33:00   0 days 00:18:00             18
# 40 2025-05-02 07:15:00 2025-05-02 07:38:00   0 days 00:23:00             23
# 41 2025-05-02 07:20:00 2025-05-02 07:41:00   0 days 00:21:00             21
# 42 2025-05-02 07:20:00 2025-05-02 07:59:00   0 days 00:39:00             39
# 43 2025-05-02 07:20:00 2025-05-02 07:44:00   0 days 00:24:00             24
# 44 2025-05-02 07:20:00 2025-05-02 07:40:00   0 days 00:20:00             20
# 45 2025-05-02 07:25:00 2025-05-02 07:46:00   0 days 00:21:00             21
# 46 2025-05-02 07:25:00 2025-05-02 07:43:00   0 days 00:18:00             18
# 47 2025-05-02 07:25:00 2025-05-02 07:53:00   0 days 00:28:00             28
# 48 2025-05-02 07:30:00 2025-05-02 07:49:00   0 days 00:19:00             19
# 49 2025-05-02 07:30:00 2025-05-02 07:56:00   0 days 00:26:00             26
#
#
# web-scraper-order                 object
# web-scraper-start-url             object
# page                             float64
# page2                            float64
# page3                            float64
# page4                            float64
# page5                            float64
# page6                            float64
# page7                            float64
# TIME                              object
# FLIGHT                            object
# DESTINATION                       object
# AIRLINE                           object
# AIRCRAFT                          object
# STATUS                            object
# DATETIME                  datetime64[ns]
# DESTINATION_CLEAN                 object
# IATA_CODE                         object
# CANCELED                            bool
# DEPART_TIME                       object
# DEPART_DATETIME           datetime64[ns]
# AIRLINE_CLEAN                     object
# AIRCRAFT_SHORT                    object
# DELAY                    timedelta64[ns]
# DELAY_MINUTES                      int64
# dtype: object
# (383, 25)

# %% [markdown]
# ## Showing full DataFrame

# %%
flightradar.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746256881-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746256881-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746256881-3  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  ...  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
#
#              DATETIME DESTINATION_CLEAN IATA_CODE CANCELED DEPART_TIME  \
# 0 2025-05-02 05:45:00           Antalya       AYT    False       06:07
# 1 2025-05-02 05:45:00          Pristina       PRN    False         NaN
# 2 2025-05-02 05:45:00          Pristina       PRN    False       06:11
#
#       DEPART_DATETIME   AIRLINE_CLEAN AIRCRAFT_SHORT             DELAY  \
# 0 2025-05-02 06:07:00   Edelweiss Air           A359   0 days 00:22:00
# 1 2025-05-02 00:00:00      Flexflight            320 -1 days +18:15:00
# 2 2025-05-02 06:11:00  Chair Airlines           A320   0 days 00:26:00
#
#   DELAY_MINUTES
# 0            22
# 1          -345
# 2            26
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Creating a New DataFrame with Selected Columns

# %%
# Create a new DataFrame with selected columns
flightradar_clean = flightradar[[
    "DESTINATION_CLEAN", 
    "IATA_CODE", 
    "AIRLINE_CLEAN", 
    "AIRCRAFT_SHORT", 
    "CANCELED", 
    "DATETIME",
    "DEPART_TIME", 
    "DEPART_DATETIME", 
    "DELAY_MINUTES"
]].copy()

# Check the result
print(flightradar_clean.head(50))
print("\n")
print(flightradar_clean.dtypes)
print(flightradar_clean.shape)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Antalya       AYT     Edelweiss Air           A359     False
# 1            Pristina       PRN        Flexflight            320     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4              Bilbao       BIO     Edelweiss Air           A320     False
# 5              Lisbon       LIS  TAP Air Portugal           A20N     False
# 6            Pristina       PRN     Edelweiss Air           A320     False
# 7               Porto       OPO             Swiss           BCS3     False
# 8     Sharm el-Sheikh       SSH     Edelweiss Air           A320     False
# 9             Seville       SVQ     Edelweiss Air           A320     False
# 10       Gran Canaria       LPA     Edelweiss Air           A320     False
# 11            Funchal       FNC     Edelweiss Air           A320     False
# 12            Larnaca       LCA     Edelweiss Air           A320     False
# 13             Dublin       DUB  Helvetic Airways           E290     False
# 14           Tenerife       TFS     Edelweiss Air           A320     False
# 15           Hurghada       HRG        Flexflight            320     False
# 16           Hurghada       HRG    Chair Airlines           A320     False
# 17          Edinburgh       EDI     Edelweiss Air           A320     False
# 18  Palma de Mallorca       PMI             Swiss           A321     False
# 19           Hurghada       HRG     Edelweiss Air           A320     False
# 20         Birmingham       BHX             Swiss           BCS3     False
# 21             Gdansk       GDN  Helvetic Airways           E190     False
# 22          Frankfurt       FRA  Helvetic Airways           E190     False
# 23           Belgrade       BEG             Swiss           BCS3     False
# 24             Kosice       KSC        Air Baltic           BCS3     False
# 25             Madrid       MAD  Helvetic Airways           E295     False
# 26           Belgrade       BEG             Swiss           BCS3     False
# 27          Amsterdam       AMS               KLM           B738     False
# 28             Tirana       TIA  Helvetic Airways           E290     False
# 29             Naples       NAP             Swiss           A320     False
# 30            Palermo       PMO             Swiss           A20N     False
# 31             London       LHR             Swiss           A21N     False
# 32             Warsaw       WAW  Helvetic Airways           E190     False
# 33         Manchester       MAN             Swiss           BCS3     False
# 34         Copenhagen       CPH             Swiss           A320     False
# 35          Barcelona       BCN             Swiss           A321     False
# 36           Budapest       BUD        Air Baltic           BCS3     False
# 37             London       LHR   British Airways           A20N     False
# 38            Hamburg       HAM  Helvetic Airways           E295     False
# 39             Munich       MUC     Edelweiss Air           A320     False
# 40             Krakow       KRK  Helvetic Airways           E195     False
# 41             Berlin       BER             Swiss           BCS1     False
# 42          Amsterdam       AMS             Swiss           A20N     False
# 43             Vienna       VIE             Swiss           A320     False
# 44               Rome       FCO             Swiss           A320     False
# 45              Paris       CDG             Swiss           A320     False
# 46           Brussels       BRU             Swiss           A320     False
# 47             Geneva       GVA             Swiss           A321     False
# 48             Madrid       MAD            Iberia           A20N     False
# 49               Nice       NCE             Swiss           BCS3     False
#
#               DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0  2025-05-02 05:45:00       06:07 2025-05-02 06:07:00             22
# 1  2025-05-02 05:45:00         NaN 2025-05-02 00:00:00           -345
# 2  2025-05-02 05:45:00       06:11 2025-05-02 06:11:00             26
# 3  2025-05-02 06:00:00       06:13 2025-05-02 06:13:00             13
# 4  2025-05-02 06:00:00       06:28 2025-05-02 06:28:00             28
# 5  2025-05-02 06:10:00       06:41 2025-05-02 06:41:00             31
# 6  2025-05-02 06:10:00       06:50 2025-05-02 06:50:00             40
# 7  2025-05-02 06:20:00       06:52 2025-05-02 06:52:00             32
# 8  2025-05-02 06:20:00       06:30 2025-05-02 06:30:00             10
# 9  2025-05-02 06:20:00       06:35 2025-05-02 06:35:00             15
# 10 2025-05-02 06:25:00       07:01 2025-05-02 07:01:00             36
# 11 2025-05-02 06:25:00       06:56 2025-05-02 06:56:00             31
# 12 2025-05-02 06:25:00       06:55 2025-05-02 06:55:00             30
# 13 2025-05-02 06:30:00       06:38 2025-05-02 06:38:00              8
# 14 2025-05-02 06:30:00       07:11 2025-05-02 07:11:00             41
# 15 2025-05-02 06:30:00         NaN 2025-05-02 00:00:00           -390
# 16 2025-05-02 06:30:00       06:44 2025-05-02 06:44:00             14
# 17 2025-05-02 06:35:00       06:42 2025-05-02 06:42:00              7
# 18 2025-05-02 06:45:00       06:58 2025-05-02 06:58:00             13
# 19 2025-05-02 06:45:00       07:05 2025-05-02 07:05:00             20
# 20 2025-05-02 06:50:00       07:10 2025-05-02 07:10:00             20
# 21 2025-05-02 06:50:00       07:06 2025-05-02 07:06:00             16
# 22 2025-05-02 06:55:00       07:08 2025-05-02 07:08:00             13
# 23 2025-05-02 06:55:00         NaN 2025-05-02 00:00:00           -415
# 24 2025-05-02 06:55:00       07:13 2025-05-02 07:13:00             18
# 25 2025-05-02 06:55:00       07:35 2025-05-02 07:35:00             40
# 26 2025-05-02 06:55:00       07:16 2025-05-02 07:16:00             21
# 27 2025-05-02 07:00:00       07:23 2025-05-02 07:23:00             23
# 28 2025-05-02 07:00:00       07:21 2025-05-02 07:21:00             21
# 29 2025-05-02 07:00:00       07:18 2025-05-02 07:18:00             18
# 30 2025-05-02 07:00:00       07:14 2025-05-02 07:14:00             14
# 31 2025-05-02 07:05:00       07:27 2025-05-02 07:27:00             22
# 32 2025-05-02 07:05:00       07:19 2025-05-02 07:19:00             14
# 33 2025-05-02 07:05:00       08:48 2025-05-02 08:48:00            103
# 34 2025-05-02 07:10:00       07:25 2025-05-02 07:25:00             15
# 35 2025-05-02 07:10:00       07:37 2025-05-02 07:37:00             27
# 36 2025-05-02 07:10:00       07:28 2025-05-02 07:28:00             18
# 37 2025-05-02 07:15:00       07:32 2025-05-02 07:32:00             17
# 38 2025-05-02 07:15:00       07:30 2025-05-02 07:30:00             15
# 39 2025-05-02 07:15:00       07:33 2025-05-02 07:33:00             18
# 40 2025-05-02 07:15:00       07:38 2025-05-02 07:38:00             23
# 41 2025-05-02 07:20:00       07:41 2025-05-02 07:41:00             21
# 42 2025-05-02 07:20:00       07:59 2025-05-02 07:59:00             39
# 43 2025-05-02 07:20:00       07:44 2025-05-02 07:44:00             24
# 44 2025-05-02 07:20:00       07:40 2025-05-02 07:40:00             20
# 45 2025-05-02 07:25:00       07:46 2025-05-02 07:46:00             21
# 46 2025-05-02 07:25:00       07:43 2025-05-02 07:43:00             18
# 47 2025-05-02 07:25:00       07:53 2025-05-02 07:53:00             28
# 48 2025-05-02 07:30:00       07:49 2025-05-02 07:49:00             19
# 49 2025-05-02 07:30:00       07:56 2025-05-02 07:56:00             26
#
#
# DESTINATION_CLEAN            object
# IATA_CODE                    object
# AIRLINE_CLEAN                object
# AIRCRAFT_SHORT               object
# CANCELED                       bool
# DATETIME             datetime64[ns]
# DEPART_TIME                  object
# DEPART_DATETIME      datetime64[ns]
# DELAY_MINUTES                 int64
# dtype: object
# (383, 9)

# %% [markdown]
# ## Count missing values in columns

# %%
# Count missing values per column
print(flightradar_clean.isnull().sum())

# Total number of missing values in the DataFrame
print("Total missing values:", flightradar_clean.isnull().sum().sum())
# Out:
# DESTINATION_CLEAN     0
# IATA_CODE             0
# AIRLINE_CLEAN         3
# AIRCRAFT_SHORT        0
# CANCELED              0
# DATETIME              0
# DEPART_TIME          10
# DEPART_DATETIME       0
# DELAY_MINUTES         0
# dtype: int64
# Total missing values: 13

# %% [markdown]
# ## Show rows with missing values in the DataFrame

# %%
# Filter rows with any missing values
missing_rows = flightradar_clean[flightradar_clean.isnull().any(axis=1)]

# Display rows with missing values
print(missing_rows)
# Out:
#      DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 1             Pristina       PRN        Flexflight            320     False
# 15            Hurghada       HRG        Flexflight            320     False
# 23            Belgrade       BEG             Swiss           BCS3     False
# 53           Heraklion       HER        Flexflight            319     False
# 63             Hamburg       HAM             Swiss           BCS3      True
# 83            Istanbul       IST  Turkish Airlines            310      True
# 113           Portoroz       POW               NaN           M600     False
# 119             Geneva       GVA               NaN           SR22     False
# 125           Helsinki       HEL           Finnair            32B      True
# 129             Dublin       DUB             Swiss           A20N     False
# 142  Palma de Mallorca       PMI    Chair Airlines           A320     False
# 232             Odense       ODE               NaN           BE20     False
# 322           Helsinki       HEL           Finnair            32B      True
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 1   2025-05-02 05:45:00         NaN 2025-05-02 00:00:00           -345
# 15  2025-05-02 06:30:00         NaN 2025-05-02 00:00:00           -390
# 23  2025-05-02 06:55:00         NaN 2025-05-02 00:00:00           -415
# 53  2025-05-02 07:40:00         NaN 2025-05-02 00:00:00           -460
# 63  2025-05-02 08:30:00         NaN 2025-05-02 00:00:00           -510
# 83  2025-05-02 09:15:00         NaN 2025-05-02 00:00:00           -555
# 113 2025-05-02 10:15:00       10:32 2025-05-02 10:32:00             17
# 119 2025-05-02 10:35:00       10:51 2025-05-02 10:51:00             16
# 125 2025-05-02 10:50:00         NaN 2025-05-02 00:00:00           -650
# 129 2025-05-02 10:50:00         NaN 2025-05-02 00:00:00           -650
# 142 2025-05-02 11:30:00         NaN 2025-05-02 00:00:00           -690
# 232 2025-05-02 15:00:00       15:13 2025-05-02 15:13:00             13
# 322 2025-05-02 19:05:00         NaN 2025-05-02 00:00:00          -1145

# %% [markdown]
# ## Show the DataFrame without missing values

# %%
# Drop rows with any missing values (NaN)
flightradar_clean = flightradar_clean.dropna(axis=0)

# Display the DataFrame after dropping rows with missing values
print(flightradar_clean)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Antalya       AYT     Edelweiss Air           A359     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4              Bilbao       BIO     Edelweiss Air           A320     False
# 5              Lisbon       LIS  TAP Air Portugal           A20N     False
# ..                ...       ...               ...            ...       ...
# 378         Sao Paulo       GRU             Swiss           B77W     False
# 379         Hong Kong       HKG             Swiss           B77W     False
# 380         Singapore       SIN             Swiss           B77W     False
# 381      Johannesburg       JNB             Swiss           A343     False
# 382             Milan       MXP  Helvetic Airways           E190     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0   2025-05-02 05:45:00       06:07 2025-05-02 06:07:00             22
# 2   2025-05-02 05:45:00       06:11 2025-05-02 06:11:00             26
# 3   2025-05-02 06:00:00       06:13 2025-05-02 06:13:00             13
# 4   2025-05-02 06:00:00       06:28 2025-05-02 06:28:00             28
# 5   2025-05-02 06:10:00       06:41 2025-05-02 06:41:00             31
# ..                  ...         ...                 ...            ...
# 378 2025-05-02 22:40:00       23:09 2025-05-02 23:09:00             29
# 379 2025-05-02 22:40:00       22:48 2025-05-02 22:48:00              8
# 380 2025-05-02 22:40:00       22:50 2025-05-02 22:50:00             10
# 381 2025-05-02 22:40:00       23:11 2025-05-02 23:11:00             31
# 382 2025-05-02 22:40:00       22:54 2025-05-02 22:54:00             14
#
# [370 rows x 9 columns]

# %% [markdown]
# ## Check for duplicate rows in the DataFrame and display them if any exist

# %%
# Duplikate prüfen
duplicates = flightradar_clean[flightradar_clean.duplicated()]

# Duplikate anzeigen (falls vorhanden)
print(duplicates)

# Anzahl der Duplikate
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [DESTINATION_CLEAN, IATA_CODE, AIRLINE_CLEAN, AIRCRAFT_SHORT, CANCELED, DATETIME, DEPART_TIME, DEPART_DATETIME, DELAY_MINUTES]
# Index: []
# Number of duplicate rows: 0

# %% [markdown]
# ## Save the cleaned DataFrame to a CSV file for further use or analysis

# %%
# Speichern des DataFrames als CSV-Datei
flightradar_clean.to_csv("250502_flightradar_prepared.csv", index=False)
