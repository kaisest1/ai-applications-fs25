# %% [markdown]
# # Data preparation
# ## Read and show Excel data for one day from Flightradar

# %%
import pandas as pd

# %%
# XLSX-Datei laden
flightradar = pd.read_excel("250503_flightradar.xlsx")

# Erste 5 Zeilen anzeigen
print(flightradar.head(5))
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746350608-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746350608-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746350608-3  https://www.flightradar24.com/data/airports/zr...   NaN
# 3      1746350608-4  https://www.flightradar24.com/data/airports/zr...   NaN
# 4      1746350608-5  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  FLIGHT  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   WK186
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22160
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   CS600
# 3    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK130
# 4    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK398
#
#        DESTINATION                                 AIRLINE       AIRCRAFT  \
# 0   Antalya (AYT)-  Edelweiss Air (Help Alliance Livery) -  A320 (HB-JLT)
# 1  Pristina (PRN)-                            Flexflight -         320 ()
# 2  Pristina (PRN)-                        Chair Airlines -  A320 (HB-JOS)
# 3  Hurghada (HRG)-                         Edelweiss Air -  A320 (HB-JLS)
# 4   Catania (CTA)-                                 Swiss -  A320 (HB-IJI)
#
#            STATUS
# 0  Departed 06:00
# 1         Unknown
# 2  Departed 06:02
# 3  Departed 06:05
# 4  Departed 06:07

# %% [markdown]
# ## Show data types and shape of the DataFrame

# %%
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# dtype: object
# (362, 15)

# %% [markdown]
# ## The Date is missing in the DataFrame. Create a new field DATETIME
# ### DATETIME is the planned departure time for that day

# %%
# Datum als Variable definieren
date_str = "2025-05-03"

# %%
# TIME als String sicherstellen (falls es z. B. float ist)
flightradar["TIME"] = flightradar["TIME"].astype(str)

# DATETIME-Feld erzeugen: 'date_str' + Zeit aus TIME-Feld
flightradar["DATETIME"] = date_str + " " + flightradar["TIME"]

# Kontrolle
print(flightradar[["TIME", "DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#         TIME             DATETIME
# 0   05:45:00  2025-05-03 05:45:00
# 1   05:45:00  2025-05-03 05:45:00
# 2   05:45:00  2025-05-03 05:45:00
# 3   06:00:00  2025-05-03 06:00:00
# 4   06:00:00  2025-05-03 06:00:00
# 5   06:10:00  2025-05-03 06:10:00
# 6   06:10:00  2025-05-03 06:10:00
# 7   06:20:00  2025-05-03 06:20:00
# 8   06:20:00  2025-05-03 06:20:00
# 9   06:25:00  2025-05-03 06:25:00
# 10  06:25:00  2025-05-03 06:25:00
# 11  06:25:00  2025-05-03 06:25:00
# 12  06:30:00  2025-05-03 06:30:00
# 13  06:30:00  2025-05-03 06:30:00
# 14  06:30:00  2025-05-03 06:30:00
# 15  06:30:00  2025-05-03 06:30:00
# 16  06:30:00  2025-05-03 06:30:00
# 17  06:35:00  2025-05-03 06:35:00
# 18  06:40:00  2025-05-03 06:40:00
# 19  06:45:00  2025-05-03 06:45:00
# 20  06:50:00  2025-05-03 06:50:00
# 21  06:50:00  2025-05-03 06:50:00
# 22  06:50:00  2025-05-03 06:50:00
# 23  06:55:00  2025-05-03 06:55:00
# 24  06:55:00  2025-05-03 06:55:00
# 25  06:55:00  2025-05-03 06:55:00
# 26  07:00:00  2025-05-03 07:00:00
# 27  07:00:00  2025-05-03 07:00:00
# 28  07:00:00  2025-05-03 07:00:00
# 29  07:00:00  2025-05-03 07:00:00
# 30  07:05:00  2025-05-03 07:05:00
# 31  07:05:00  2025-05-03 07:05:00
# 32  07:05:00  2025-05-03 07:05:00
# 33  07:05:00  2025-05-03 07:05:00
# 34  07:10:00  2025-05-03 07:10:00
# 35  07:10:00  2025-05-03 07:10:00
# 36  07:10:00  2025-05-03 07:10:00
# 37  07:10:00  2025-05-03 07:10:00
# 38  07:15:00  2025-05-03 07:15:00
# 39  07:15:00  2025-05-03 07:15:00
# 40  07:15:00  2025-05-03 07:15:00
# 41  07:15:00  2025-05-03 07:15:00
# 42  07:15:00  2025-05-03 07:15:00
# 43  07:20:00  2025-05-03 07:20:00
# 44  07:20:00  2025-05-03 07:20:00
# 45  07:20:00  2025-05-03 07:20:00
# 46  07:20:00  2025-05-03 07:20:00
# 47  07:20:00  2025-05-03 07:20:00
# 48  07:25:00  2025-05-03 07:25:00
# 49  07:25:00  2025-05-03 07:25:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# dtype: object
# (362, 16)

# %% [markdown]
# ## Create two new fields: DESTINATION_CLEAN and IATA_CODE using regex

# %%
# DESTINATION_CLEAN: Alles vor der Klammer
flightradar["DESTINATION_CLEAN"] = flightradar["DESTINATION"].str.extract(r"^(.*?)\s*\(")

# IATA-CODE: Inhalt in der Klammer
flightradar["IATA_CODE"] = flightradar["DESTINATION"].str.extract(r"\((\w{3})\)")

# Kontrolle
print(flightradar[["DESTINATION", "DESTINATION_CLEAN", "IATA_CODE"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                  DESTINATION  DESTINATION_CLEAN IATA_CODE
# 0             Antalya (AYT)-            Antalya       AYT
# 1            Pristina (PRN)-           Pristina       PRN
# 2            Pristina (PRN)-           Pristina       PRN
# 3            Hurghada (HRG)-           Hurghada       HRG
# 4             Catania (CTA)-            Catania       CTA
# 5            Tenerife (TFS)-           Tenerife       TFS
# 6             Funchal (FNC)-            Funchal       FNC
# 7               Porto (OPO)-              Porto       OPO
# 8              Lisbon (LIS)-             Lisbon       LIS
# 9             Larnaca (LCA)-            Larnaca       LCA
# 10           Cagliari (CAG)-           Cagliari       CAG
# 11           Pristina (PRN)-           Pristina       PRN
# 12             Tromso (TOS)-             Tromso       TOS
# 13           Hurghada (HRG)-           Hurghada       HRG
# 14            Larnaca (LCA)-            Larnaca       LCA
# 15           Hurghada (HRG)-           Hurghada       HRG
# 16            Larnaca (LCA)-            Larnaca       LCA
# 17             Dublin (DUB)-             Dublin       DUB
# 18    Sharm el-Sheikh (SSH)-    Sharm el-Sheikh       SSH
# 19  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 20              Sofia (SOF)-              Sofia       SOF
# 21           Brindisi (BDS)-           Brindisi       BDS
# 22        Cluj-Napoca (CLJ)-        Cluj-Napoca       CLJ
# 23          Frankfurt (FRA)-          Frankfurt       FRA
# 24           Belgrade (BEG)-           Belgrade       BEG
# 25             Madrid (MAD)-             Madrid       MAD
# 26          Amsterdam (AMS)-          Amsterdam       AMS
# 27             Krakow (KRK)-             Krakow       KRK
# 28           Sarajevo (SJJ)-           Sarajevo       SJJ
# 29            Palermo (PMO)-            Palermo       PMO
# 30             London (LHR)-             London       LHR
# 31             Naples (NAP)-             Naples       NAP
# 32          Ljubljana (LJU)-          Ljubljana       LJU
# 33         Manchester (MAN)-         Manchester       MAN
# 34         Dusseldorf (DUS)-         Dusseldorf       DUS
# 35         Copenhagen (CPH)-         Copenhagen       CPH
# 36          Barcelona (BCN)-          Barcelona       BCN
# 37           Budapest (BUD)-           Budapest       BUD
# 38             London (LHR)-             London       LHR
# 39            Hamburg (HAM)-            Hamburg       HAM
# 40             Munich (MUC)-             Munich       MUC
# 41            Bologna (BLQ)-            Bologna       BLQ
# 42             Geneva (GVA)-             Geneva       GVA
# 43          Amsterdam (AMS)-          Amsterdam       AMS
# 44             Berlin (BER)-             Berlin       BER
# 45             Vienna (VIE)-             Vienna       VIE
# 46               Rome (FCO)-               Rome       FCO
# 47               Faro (FAO)-               Faro       FAO
# 48               Nice (NCE)-               Nice       NCE
# 49              Paris (CDG)-              Paris       CDG
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# dtype: object
# (362, 18)

# %% [markdown]
# ## Create three new fields: CANCELED, DEPART_TIME and DEPART_DATETIME using regex

# %%
# 1. CANCELED-Spalte (Boolean)
flightradar["CANCELED"] = flightradar["STATUS"].str.contains("Canceled", na=False)

# 2. DEPART_TIME-Spalte (nur wenn "Departed HH:MM" enthalten ist)
flightradar["DEPART_TIME"] = flightradar["STATUS"].str.extract(r"Departed\s*(\d{2}:\d{2})")[0]

# 3. DEPART_DATETIME-Spalte: date_str + DEPART_TIME (fallback "00:00") + ":00"
flightradar["DEPART_DATETIME"] = (
    date_str
    + " "
    + flightradar["DEPART_TIME"].fillna("00:00") # falls keine Zeit da ist, setze "00:00"
    + ":00" # Sekunden anhängen
)

# Kontrolle
print(flightradar[["STATUS","CANCELED","DEPART_TIME","DEPART_DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#             STATUS  CANCELED DEPART_TIME      DEPART_DATETIME
# 0   Departed 06:00     False       06:00  2025-05-03 06:00:00
# 1          Unknown     False         NaN  2025-05-03 00:00:00
# 2   Departed 06:02     False       06:02  2025-05-03 06:02:00
# 3   Departed 06:05     False       06:05  2025-05-03 06:05:00
# 4   Departed 06:07     False       06:07  2025-05-03 06:07:00
# 5   Departed 06:31     False       06:31  2025-05-03 06:31:00
# 6   Departed 06:28     False       06:28  2025-05-03 06:28:00
# 7   Departed 06:36     False       06:36  2025-05-03 06:36:00
# 8   Departed 06:44     False       06:44  2025-05-03 06:44:00
# 9   Departed 06:42     False       06:42  2025-05-03 06:42:00
# 10  Departed 07:41     False       07:41  2025-05-03 07:41:00
# 11  Departed 06:37     False       06:37  2025-05-03 06:37:00
# 12  Departed 06:34     False       06:34  2025-05-03 06:34:00
# 13         Unknown     False         NaN  2025-05-03 00:00:00
# 14         Unknown     False         NaN  2025-05-03 00:00:00
# 15  Departed 06:51     False       06:51  2025-05-03 06:51:00
# 16  Departed 06:46     False       06:46  2025-05-03 06:46:00
# 17  Departed 06:47     False       06:47  2025-05-03 06:47:00
# 18  Departed 06:56     False       06:56  2025-05-03 06:56:00
# 19  Departed 06:59     False       06:59  2025-05-03 06:59:00
# 20  Departed 07:10     False       07:10  2025-05-03 07:10:00
# 21  Departed 07:01     False       07:01  2025-05-03 07:01:00
# 22  Departed 07:20     False       07:20  2025-05-03 07:20:00
# 23  Departed 07:08     False       07:08  2025-05-03 07:08:00
# 24  Departed 07:04     False       07:04  2025-05-03 07:04:00
# 25  Departed 07:10     False       07:10  2025-05-03 07:10:00
# 26  Departed 07:15     False       07:15  2025-05-03 07:15:00
# 27  Departed 07:23     False       07:23  2025-05-03 07:23:00
# 28  Departed 07:19     False       07:19  2025-05-03 07:19:00
# 29  Departed 07:30     False       07:30  2025-05-03 07:30:00
# 30  Departed 07:13     False       07:13  2025-05-03 07:13:00
# 31  Departed 07:14     False       07:14  2025-05-03 07:14:00
# 32  Departed 07:17     False       07:17  2025-05-03 07:17:00
# 33  Departed 07:19     False       07:19  2025-05-03 07:19:00
# 34  Departed 07:30     False       07:30  2025-05-03 07:30:00
# 35  Departed 07:25     False       07:25  2025-05-03 07:25:00
# 36  Departed 07:23     False       07:23  2025-05-03 07:23:00
# 37  Departed 07:35     False       07:35  2025-05-03 07:35:00
# 38  Departed 07:25     False       07:25  2025-05-03 07:25:00
# 39  Departed 07:28     False       07:28  2025-05-03 07:28:00
# 40  Departed 07:33     False       07:33  2025-05-03 07:33:00
# 41  Departed 07:45     False       07:45  2025-05-03 07:45:00
# 42  Departed 07:32     False       07:32  2025-05-03 07:32:00
# 43  Departed 07:42     False       07:42  2025-05-03 07:42:00
# 44  Departed 07:40     False       07:40  2025-05-03 07:40:00
# 45  Departed 07:37     False       07:37  2025-05-03 07:37:00
# 46  Departed 07:35     False       07:35  2025-05-03 07:35:00
# 47  Departed 07:28     False       07:28  2025-05-03 07:28:00
# 48  Departed 07:37     False       07:37  2025-05-03 07:37:00
# 49  Departed 07:42     False       07:42  2025-05-03 07:42:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# dtype: object
# (362, 21)

# %% [markdown]
# ## Creating the AIRLINE_CLEAN field and removing unimportant parts

# %%
flightradar["AIRLINE_CLEAN"] = (
    flightradar["AIRLINE"]
      .str.extract(r'^(.+?)(?=\s*(?:\(|-))')[0]  # Gruppe 1: alles bis vor "(" oder "-"
      .str.strip()                               # führende/trailing Leerzeichen entfernen
)

# Kontrolle
print(flightradar[["AIRLINE","AIRLINE_CLEAN"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                                    AIRLINE     AIRLINE_CLEAN
# 0   Edelweiss Air (Help Alliance Livery) -     Edelweiss Air
# 1                             Flexflight -        Flexflight
# 2                         Chair Airlines -    Chair Airlines
# 3                          Edelweiss Air -     Edelweiss Air
# 4                                  Swiss -             Swiss
# 5                          Edelweiss Air -     Edelweiss Air
# 6                          Edelweiss Air -     Edelweiss Air
# 7                                  Swiss -             Swiss
# 8                       TAP Air Portugal -  TAP Air Portugal
# 9                          Edelweiss Air -     Edelweiss Air
# 10                         Edelweiss Air -     Edelweiss Air
# 11                         Edelweiss Air -     Edelweiss Air
# 12                         Edelweiss Air -     Edelweiss Air
# 13                            Flexflight -        Flexflight
# 14                            Flexflight -        Flexflight
# 15                        Chair Airlines -    Chair Airlines
# 16                        Chair Airlines -    Chair Airlines
# 17                      Helvetic Airways -  Helvetic Airways
# 18                         Edelweiss Air -     Edelweiss Air
# 19                                 Swiss -             Swiss
# 20                      Helvetic Airways -  Helvetic Airways
# 21                                 Swiss -             Swiss
# 22                                 Swiss -             Swiss
# 23                      Helvetic Airways -  Helvetic Airways
# 24                            Air Baltic -        Air Baltic
# 25                      Helvetic Airways -  Helvetic Airways
# 26                                   KLM -               KLM
# 27                      Helvetic Airways -  Helvetic Airways
# 28                                 Swiss -             Swiss
# 29                                 Swiss -             Swiss
# 30                                 Swiss -             Swiss
# 31                                 Swiss -             Swiss
# 32                      Helvetic Airways -  Helvetic Airways
# 33                                 Swiss -             Swiss
# 34                      Helvetic Airways -  Helvetic Airways
# 35                      Helvetic Airways -  Helvetic Airways
# 36          Swiss (Star Alliance Livery) -             Swiss
# 37                            Air Baltic -        Air Baltic
# 38                       British Airways -   British Airways
# 39                                 Swiss -             Swiss
# 40                                 Swiss -             Swiss
# 41                                 Swiss -             Swiss
# 42                                 Swiss -             Swiss
# 43                      Helvetic Airways -  Helvetic Airways
# 44                                 Swiss -             Swiss
# 45                                 Swiss -             Swiss
# 46                                 Swiss -             Swiss
# 47                   Swiss Air-Ambulance -         Swiss Air
# 48                      Helvetic Airways -  Helvetic Airways
# 49                         Edelweiss Air -     Edelweiss Air
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# dtype: object
# (362, 22)

# %% [markdown]
# ## Creating the AIRCRAFT_SHORT field

# %%
# Create the AIRCRAFT_SHORT field by removing text inside parentheses
flightradar["AIRCRAFT_SHORT"] = (
    flightradar["AIRCRAFT"]
      .str.replace(r"\s*\(.*?\)", "", regex=True)  # non‑greedy, regex=True
      .str.strip()
)

# Check the result
print(flightradar[["AIRCRAFT", "AIRCRAFT_SHORT"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#          AIRCRAFT AIRCRAFT_SHORT
# 0   A320 (HB-JLT)           A320
# 1          320 ()            320
# 2   A320 (HB-JOS)           A320
# 3   A320 (HB-JLS)           A320
# 4   A320 (HB-IJI)           A320
# 5   A320 (HB-IJU)           A320
# 6   A320 (HB-IHX)           A320
# 7   BCS3 (HB-JCT)           BCS3
# 8   A321 (CS-TJE)           A321
# 9   A320 (HB-IJV)           A320
# 10  A320 (HB-IJW)           A320
# 11  A359 (HB-IHF)           A359
# 12  A320 (HB-JLR)           A320
# 13         320 ()            320
# 14         319 ()            319
# 15  A320 (HB-JOK)           A320
# 16  A319 (HB-JOJ)           A319
# 17  E290 (HB-AZC)           E290
# 18  A320 (HB-IHZ)           A320
# 19  A21N (HB-JPC)           A21N
# 20  E290 (HB-AZG)           E290
# 21  A21N (HB-JPD)           A21N
# 22  BCS1 (HB-JBC)           BCS1
# 23  E195 (HB-JVJ)           E195
# 24  BCS3 (YL-AAW)           BCS3
# 25  E295 (HB-AZL)           E295
# 26  B738 (PH-BGA)           B738
# 27  E190 (HB-JVO)           E190
# 28  BCS3 (HB-JCF)           BCS3
# 29  BCS3 (HB-JCE)           BCS3
# 30  A20N (HB-JDI)           A20N
# 31  A320 (HB-IJK)           A320
# 32  E295 (HB-AZJ)           E295
# 33  BCS1 (HB-JBD)           BCS1
# 34  E295 (HB-AZI)           E295
# 35  E195 (HB-JVW)           E195
# 36  A320 (HB-IJM)           A320
# 37  BCS3 (YL-CSH)           BCS3
# 38  A20N (G-TTNO)           A20N
# 39  BCS1 (HB-JBE)           BCS1
# 40  BCS1 (HB-JBH)           BCS1
# 41  BCS1 (HB-JBB)           BCS1
# 42  BCS3 (HB-JCD)           BCS3
# 43  E290 (HB-AZA)           E290
# 44  A320 (HB-IJR)           A320
# 45  A320 (HB-IJJ)           A320
# 46  A321 (HB-IOM)           A321
# 47  CL60 (HB-JWC)           CL60
# 48  E195 (HB-JVA)           E195
# 49  A320 (HB-JJK)           A320
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# AIRCRAFT_SHORT            object
# dtype: object
# (362, 23)

# %% [markdown]
# ## Create a new field DELAY and DELAY_MINUTES and calculate it from DATETIME and DEPART_DATETIME

# %%
# 1) Stelle sicher, dass beide Spalten als datetime64 vorliegen
flightradar["DATETIME"] = pd.to_datetime(flightradar["DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
flightradar["DEPART_DATETIME"] = pd.to_datetime(flightradar["DEPART_DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")

# 2) DELAY als Differenz berechnen
flightradar["DELAY"] = flightradar["DEPART_DATETIME"] - flightradar["DATETIME"]

# 3a) Variante A: Floor‑Division auf total_seconds, dann in int
flightradar["DELAY_MINUTES"] = (
    flightradar["DELAY"].dt.total_seconds() // 60
).astype(int)

# Kontrolle
print(flightradar[["DATETIME","DEPART_DATETIME","DELAY","DELAY_MINUTES"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#               DATETIME     DEPART_DATETIME             DELAY  DELAY_MINUTES
# 0  2025-05-03 05:45:00 2025-05-03 06:00:00   0 days 00:15:00             15
# 1  2025-05-03 05:45:00 2025-05-03 00:00:00 -1 days +18:15:00           -345
# 2  2025-05-03 05:45:00 2025-05-03 06:02:00   0 days 00:17:00             17
# 3  2025-05-03 06:00:00 2025-05-03 06:05:00   0 days 00:05:00              5
# 4  2025-05-03 06:00:00 2025-05-03 06:07:00   0 days 00:07:00              7
# 5  2025-05-03 06:10:00 2025-05-03 06:31:00   0 days 00:21:00             21
# 6  2025-05-03 06:10:00 2025-05-03 06:28:00   0 days 00:18:00             18
# 7  2025-05-03 06:20:00 2025-05-03 06:36:00   0 days 00:16:00             16
# 8  2025-05-03 06:20:00 2025-05-03 06:44:00   0 days 00:24:00             24
# 9  2025-05-03 06:25:00 2025-05-03 06:42:00   0 days 00:17:00             17
# 10 2025-05-03 06:25:00 2025-05-03 07:41:00   0 days 01:16:00             76
# 11 2025-05-03 06:25:00 2025-05-03 06:37:00   0 days 00:12:00             12
# 12 2025-05-03 06:30:00 2025-05-03 06:34:00   0 days 00:04:00              4
# 13 2025-05-03 06:30:00 2025-05-03 00:00:00 -1 days +17:30:00           -390
# 14 2025-05-03 06:30:00 2025-05-03 00:00:00 -1 days +17:30:00           -390
# 15 2025-05-03 06:30:00 2025-05-03 06:51:00   0 days 00:21:00             21
# 16 2025-05-03 06:30:00 2025-05-03 06:46:00   0 days 00:16:00             16
# 17 2025-05-03 06:35:00 2025-05-03 06:47:00   0 days 00:12:00             12
# 18 2025-05-03 06:40:00 2025-05-03 06:56:00   0 days 00:16:00             16
# 19 2025-05-03 06:45:00 2025-05-03 06:59:00   0 days 00:14:00             14
# 20 2025-05-03 06:50:00 2025-05-03 07:10:00   0 days 00:20:00             20
# 21 2025-05-03 06:50:00 2025-05-03 07:01:00   0 days 00:11:00             11
# 22 2025-05-03 06:50:00 2025-05-03 07:20:00   0 days 00:30:00             30
# 23 2025-05-03 06:55:00 2025-05-03 07:08:00   0 days 00:13:00             13
# 24 2025-05-03 06:55:00 2025-05-03 07:04:00   0 days 00:09:00              9
# 25 2025-05-03 06:55:00 2025-05-03 07:10:00   0 days 00:15:00             15
# 26 2025-05-03 07:00:00 2025-05-03 07:15:00   0 days 00:15:00             15
# 27 2025-05-03 07:00:00 2025-05-03 07:23:00   0 days 00:23:00             23
# 28 2025-05-03 07:00:00 2025-05-03 07:19:00   0 days 00:19:00             19
# 29 2025-05-03 07:00:00 2025-05-03 07:30:00   0 days 00:30:00             30
# 30 2025-05-03 07:05:00 2025-05-03 07:13:00   0 days 00:08:00              8
# 31 2025-05-03 07:05:00 2025-05-03 07:14:00   0 days 00:09:00              9
# 32 2025-05-03 07:05:00 2025-05-03 07:17:00   0 days 00:12:00             12
# 33 2025-05-03 07:05:00 2025-05-03 07:19:00   0 days 00:14:00             14
# 34 2025-05-03 07:10:00 2025-05-03 07:30:00   0 days 00:20:00             20
# 35 2025-05-03 07:10:00 2025-05-03 07:25:00   0 days 00:15:00             15
# 36 2025-05-03 07:10:00 2025-05-03 07:23:00   0 days 00:13:00             13
# 37 2025-05-03 07:10:00 2025-05-03 07:35:00   0 days 00:25:00             25
# 38 2025-05-03 07:15:00 2025-05-03 07:25:00   0 days 00:10:00             10
# 39 2025-05-03 07:15:00 2025-05-03 07:28:00   0 days 00:13:00             13
# 40 2025-05-03 07:15:00 2025-05-03 07:33:00   0 days 00:18:00             18
# 41 2025-05-03 07:15:00 2025-05-03 07:45:00   0 days 00:30:00             30
# 42 2025-05-03 07:15:00 2025-05-03 07:32:00   0 days 00:17:00             17
# 43 2025-05-03 07:20:00 2025-05-03 07:42:00   0 days 00:22:00             22
# 44 2025-05-03 07:20:00 2025-05-03 07:40:00   0 days 00:20:00             20
# 45 2025-05-03 07:20:00 2025-05-03 07:37:00   0 days 00:17:00             17
# 46 2025-05-03 07:20:00 2025-05-03 07:35:00   0 days 00:15:00             15
# 47 2025-05-03 07:20:00 2025-05-03 07:28:00   0 days 00:08:00              8
# 48 2025-05-03 07:25:00 2025-05-03 07:37:00   0 days 00:12:00             12
# 49 2025-05-03 07:25:00 2025-05-03 07:42:00   0 days 00:17:00             17
#
#
# web-scraper-order                 object
# web-scraper-start-url             object
# page                             float64
# page2                            float64
# page3                            float64
# page4                            float64
# page5                            float64
# page6                            float64
# page7                            float64
# TIME                              object
# FLIGHT                            object
# DESTINATION                       object
# AIRLINE                           object
# AIRCRAFT                          object
# STATUS                            object
# DATETIME                  datetime64[ns]
# DESTINATION_CLEAN                 object
# IATA_CODE                         object
# CANCELED                            bool
# DEPART_TIME                       object
# DEPART_DATETIME           datetime64[ns]
# AIRLINE_CLEAN                     object
# AIRCRAFT_SHORT                    object
# DELAY                    timedelta64[ns]
# DELAY_MINUTES                      int64
# dtype: object
# (362, 25)

# %% [markdown]
# ## Showing full DataFrame

# %%
flightradar.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1746350608-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1746350608-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1746350608-3  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  ...  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
#
#              DATETIME DESTINATION_CLEAN IATA_CODE CANCELED DEPART_TIME  \
# 0 2025-05-03 05:45:00           Antalya       AYT    False       06:00
# 1 2025-05-03 05:45:00          Pristina       PRN    False         NaN
# 2 2025-05-03 05:45:00          Pristina       PRN    False       06:02
#
#       DEPART_DATETIME   AIRLINE_CLEAN AIRCRAFT_SHORT             DELAY  \
# 0 2025-05-03 06:00:00   Edelweiss Air           A320   0 days 00:15:00
# 1 2025-05-03 00:00:00      Flexflight            320 -1 days +18:15:00
# 2 2025-05-03 06:02:00  Chair Airlines           A320   0 days 00:17:00
#
#   DELAY_MINUTES
# 0            15
# 1          -345
# 2            17
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Creating a New DataFrame with Selected Columns

# %%
# Create a new DataFrame with selected columns
flightradar_clean = flightradar[[
    "DESTINATION_CLEAN", 
    "IATA_CODE", 
    "AIRLINE_CLEAN", 
    "AIRCRAFT_SHORT", 
    "CANCELED", 
    "DATETIME",
    "DEPART_TIME", 
    "DEPART_DATETIME", 
    "DELAY_MINUTES"
]].copy()

# Check the result
print(flightradar_clean.head(50))
print("\n")
print(flightradar_clean.dtypes)
print(flightradar_clean.shape)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Antalya       AYT     Edelweiss Air           A320     False
# 1            Pristina       PRN        Flexflight            320     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4             Catania       CTA             Swiss           A320     False
# 5            Tenerife       TFS     Edelweiss Air           A320     False
# 6             Funchal       FNC     Edelweiss Air           A320     False
# 7               Porto       OPO             Swiss           BCS3     False
# 8              Lisbon       LIS  TAP Air Portugal           A321     False
# 9             Larnaca       LCA     Edelweiss Air           A320     False
# 10           Cagliari       CAG     Edelweiss Air           A320     False
# 11           Pristina       PRN     Edelweiss Air           A359     False
# 12             Tromso       TOS     Edelweiss Air           A320     False
# 13           Hurghada       HRG        Flexflight            320     False
# 14            Larnaca       LCA        Flexflight            319     False
# 15           Hurghada       HRG    Chair Airlines           A320     False
# 16            Larnaca       LCA    Chair Airlines           A319     False
# 17             Dublin       DUB  Helvetic Airways           E290     False
# 18    Sharm el-Sheikh       SSH     Edelweiss Air           A320     False
# 19  Palma de Mallorca       PMI             Swiss           A21N     False
# 20              Sofia       SOF  Helvetic Airways           E290     False
# 21           Brindisi       BDS             Swiss           A21N     False
# 22        Cluj-Napoca       CLJ             Swiss           BCS1     False
# 23          Frankfurt       FRA  Helvetic Airways           E195     False
# 24           Belgrade       BEG        Air Baltic           BCS3     False
# 25             Madrid       MAD  Helvetic Airways           E295     False
# 26          Amsterdam       AMS               KLM           B738     False
# 27             Krakow       KRK  Helvetic Airways           E190     False
# 28           Sarajevo       SJJ             Swiss           BCS3     False
# 29            Palermo       PMO             Swiss           BCS3     False
# 30             London       LHR             Swiss           A20N     False
# 31             Naples       NAP             Swiss           A320     False
# 32          Ljubljana       LJU  Helvetic Airways           E295     False
# 33         Manchester       MAN             Swiss           BCS1     False
# 34         Dusseldorf       DUS  Helvetic Airways           E295     False
# 35         Copenhagen       CPH  Helvetic Airways           E195     False
# 36          Barcelona       BCN             Swiss           A320     False
# 37           Budapest       BUD        Air Baltic           BCS3     False
# 38             London       LHR   British Airways           A20N     False
# 39            Hamburg       HAM             Swiss           BCS1     False
# 40             Munich       MUC             Swiss           BCS1     False
# 41            Bologna       BLQ             Swiss           BCS1     False
# 42             Geneva       GVA             Swiss           BCS3     False
# 43          Amsterdam       AMS  Helvetic Airways           E290     False
# 44             Berlin       BER             Swiss           A320     False
# 45             Vienna       VIE             Swiss           A320     False
# 46               Rome       FCO             Swiss           A321     False
# 47               Faro       FAO         Swiss Air           CL60     False
# 48               Nice       NCE  Helvetic Airways           E195     False
# 49              Paris       CDG     Edelweiss Air           A320     False
#
#               DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0  2025-05-03 05:45:00       06:00 2025-05-03 06:00:00             15
# 1  2025-05-03 05:45:00         NaN 2025-05-03 00:00:00           -345
# 2  2025-05-03 05:45:00       06:02 2025-05-03 06:02:00             17
# 3  2025-05-03 06:00:00       06:05 2025-05-03 06:05:00              5
# 4  2025-05-03 06:00:00       06:07 2025-05-03 06:07:00              7
# 5  2025-05-03 06:10:00       06:31 2025-05-03 06:31:00             21
# 6  2025-05-03 06:10:00       06:28 2025-05-03 06:28:00             18
# 7  2025-05-03 06:20:00       06:36 2025-05-03 06:36:00             16
# 8  2025-05-03 06:20:00       06:44 2025-05-03 06:44:00             24
# 9  2025-05-03 06:25:00       06:42 2025-05-03 06:42:00             17
# 10 2025-05-03 06:25:00       07:41 2025-05-03 07:41:00             76
# 11 2025-05-03 06:25:00       06:37 2025-05-03 06:37:00             12
# 12 2025-05-03 06:30:00       06:34 2025-05-03 06:34:00              4
# 13 2025-05-03 06:30:00         NaN 2025-05-03 00:00:00           -390
# 14 2025-05-03 06:30:00         NaN 2025-05-03 00:00:00           -390
# 15 2025-05-03 06:30:00       06:51 2025-05-03 06:51:00             21
# 16 2025-05-03 06:30:00       06:46 2025-05-03 06:46:00             16
# 17 2025-05-03 06:35:00       06:47 2025-05-03 06:47:00             12
# 18 2025-05-03 06:40:00       06:56 2025-05-03 06:56:00             16
# 19 2025-05-03 06:45:00       06:59 2025-05-03 06:59:00             14
# 20 2025-05-03 06:50:00       07:10 2025-05-03 07:10:00             20
# 21 2025-05-03 06:50:00       07:01 2025-05-03 07:01:00             11
# 22 2025-05-03 06:50:00       07:20 2025-05-03 07:20:00             30
# 23 2025-05-03 06:55:00       07:08 2025-05-03 07:08:00             13
# 24 2025-05-03 06:55:00       07:04 2025-05-03 07:04:00              9
# 25 2025-05-03 06:55:00       07:10 2025-05-03 07:10:00             15
# 26 2025-05-03 07:00:00       07:15 2025-05-03 07:15:00             15
# 27 2025-05-03 07:00:00       07:23 2025-05-03 07:23:00             23
# 28 2025-05-03 07:00:00       07:19 2025-05-03 07:19:00             19
# 29 2025-05-03 07:00:00       07:30 2025-05-03 07:30:00             30
# 30 2025-05-03 07:05:00       07:13 2025-05-03 07:13:00              8
# 31 2025-05-03 07:05:00       07:14 2025-05-03 07:14:00              9
# 32 2025-05-03 07:05:00       07:17 2025-05-03 07:17:00             12
# 33 2025-05-03 07:05:00       07:19 2025-05-03 07:19:00             14
# 34 2025-05-03 07:10:00       07:30 2025-05-03 07:30:00             20
# 35 2025-05-03 07:10:00       07:25 2025-05-03 07:25:00             15
# 36 2025-05-03 07:10:00       07:23 2025-05-03 07:23:00             13
# 37 2025-05-03 07:10:00       07:35 2025-05-03 07:35:00             25
# 38 2025-05-03 07:15:00       07:25 2025-05-03 07:25:00             10
# 39 2025-05-03 07:15:00       07:28 2025-05-03 07:28:00             13
# 40 2025-05-03 07:15:00       07:33 2025-05-03 07:33:00             18
# 41 2025-05-03 07:15:00       07:45 2025-05-03 07:45:00             30
# 42 2025-05-03 07:15:00       07:32 2025-05-03 07:32:00             17
# 43 2025-05-03 07:20:00       07:42 2025-05-03 07:42:00             22
# 44 2025-05-03 07:20:00       07:40 2025-05-03 07:40:00             20
# 45 2025-05-03 07:20:00       07:37 2025-05-03 07:37:00             17
# 46 2025-05-03 07:20:00       07:35 2025-05-03 07:35:00             15
# 47 2025-05-03 07:20:00       07:28 2025-05-03 07:28:00              8
# 48 2025-05-03 07:25:00       07:37 2025-05-03 07:37:00             12
# 49 2025-05-03 07:25:00       07:42 2025-05-03 07:42:00             17
#
#
# DESTINATION_CLEAN            object
# IATA_CODE                    object
# AIRLINE_CLEAN                object
# AIRCRAFT_SHORT               object
# CANCELED                       bool
# DATETIME             datetime64[ns]
# DEPART_TIME                  object
# DEPART_DATETIME      datetime64[ns]
# DELAY_MINUTES                 int64
# dtype: object
# (362, 9)

# %% [markdown]
# ## Count missing values in columns

# %%
# Count missing values per column
print(flightradar_clean.isnull().sum())

# Total number of missing values in the DataFrame
print("Total missing values:", flightradar_clean.isnull().sum().sum())
# Out:
# DESTINATION_CLEAN    0
# IATA_CODE            0
# AIRLINE_CLEAN        5
# AIRCRAFT_SHORT       0
# CANCELED             0
# DATETIME             0
# DEPART_TIME          8
# DEPART_DATETIME      0
# DELAY_MINUTES        0
# dtype: int64
# Total missing values: 13

# %% [markdown]
# ## Show rows with missing values in the DataFrame

# %%
# Filter rows with any missing values
missing_rows = flightradar_clean[flightradar_clean.isnull().any(axis=1)]

# Display rows with missing values
print(missing_rows)
# Out:
#      DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 1             Pristina       PRN        Flexflight            320     False
# 13            Hurghada       HRG        Flexflight            320     False
# 14             Larnaca       LCA        Flexflight            319     False
# 52              Madrid       MAD            Iberia           A20N     False
# 82             Leipzig       LEJ               NaN           PC12     False
# 103               Sylt       GWT               NaN           C25M     False
# 107           Florence       FLR               NaN           C525     False
# 132  Palma de Mallorca       PMI        Flexflight            320     False
# 134              Paris       LBG               NaN           CL60     False
# 202           Istanbul       ISL               NaN           GLF6     False
# 211           Istanbul       IST  Turkish Airlines            33X     False
# 305          Frankfurt       FRA             Swiss           A20N      True
# 342             Berlin       BER             Swiss           A320      True
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 1   2025-05-03 05:45:00         NaN 2025-05-03 00:00:00           -345
# 13  2025-05-03 06:30:00         NaN 2025-05-03 00:00:00           -390
# 14  2025-05-03 06:30:00         NaN 2025-05-03 00:00:00           -390
# 52  2025-05-03 07:30:00         NaN 2025-05-03 00:00:00           -450
# 82  2025-05-03 09:25:00       09:32 2025-05-03 09:32:00              7
# 103 2025-05-03 10:00:00       10:02 2025-05-03 10:02:00              2
# 107 2025-05-03 10:20:00       13:52 2025-05-03 13:52:00            212
# 132 2025-05-03 11:30:00         NaN 2025-05-03 00:00:00           -690
# 134 2025-05-03 11:30:00       11:36 2025-05-03 11:36:00              6
# 202 2025-05-03 13:30:00       13:54 2025-05-03 13:54:00             24
# 211 2025-05-03 14:25:00         NaN 2025-05-03 00:00:00           -865
# 305 2025-05-03 18:55:00         NaN 2025-05-03 00:00:00          -1135
# 342 2025-05-03 21:45:00         NaN 2025-05-03 00:00:00          -1305

# %% [markdown]
# ## Show the DataFrame without missing values

# %%
# Drop rows with any missing values (NaN)
flightradar_clean = flightradar_clean.dropna(axis=0)

# Display the DataFrame after dropping rows with missing values
print(flightradar_clean)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Antalya       AYT     Edelweiss Air           A320     False
# 2            Pristina       PRN    Chair Airlines           A320     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4             Catania       CTA             Swiss           A320     False
# 5            Tenerife       TFS     Edelweiss Air           A320     False
# ..                ...       ...               ...            ...       ...
# 357         Hong Kong       HKG             Swiss           B77W     False
# 358         Singapore       SIN             Swiss           B77W     False
# 359      Johannesburg       JNB             Swiss           A343     False
# 360             Milan       MXP  Helvetic Airways           E195     False
# 361           Tbilisi       TBS     Edelweiss Air           A320     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0   2025-05-03 05:45:00       06:00 2025-05-03 06:00:00             15
# 2   2025-05-03 05:45:00       06:02 2025-05-03 06:02:00             17
# 3   2025-05-03 06:00:00       06:05 2025-05-03 06:05:00              5
# 4   2025-05-03 06:00:00       06:07 2025-05-03 06:07:00              7
# 5   2025-05-03 06:10:00       06:31 2025-05-03 06:31:00             21
# ..                  ...         ...                 ...            ...
# 357 2025-05-03 22:40:00       23:01 2025-05-03 23:01:00             21
# 358 2025-05-03 22:40:00       22:59 2025-05-03 22:59:00             19
# 359 2025-05-03 22:40:00       23:02 2025-05-03 23:02:00             22
# 360 2025-05-03 22:40:00       23:07 2025-05-03 23:07:00             27
# 361 2025-05-03 22:45:00       22:52 2025-05-03 22:52:00              7
#
# [349 rows x 9 columns]

# %% [markdown]
# ## Check for duplicate rows in the DataFrame and display them if any exist

# %%
# Duplikate prüfen
duplicates = flightradar_clean[flightradar_clean.duplicated()]

# Duplikate anzeigen (falls vorhanden)
print(duplicates)

# Anzahl der Duplikate
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
# Empty DataFrame
# Columns: [DESTINATION_CLEAN, IATA_CODE, AIRLINE_CLEAN, AIRCRAFT_SHORT, CANCELED, DATETIME, DEPART_TIME, DEPART_DATETIME, DELAY_MINUTES]
# Index: []
# Number of duplicate rows: 0

# %% [markdown]
# ## Save the cleaned DataFrame to a CSV file for further use or analysis

# %%
# Speichern des DataFrames als CSV-Datei
flightradar_clean.to_csv("250503_flightradar_prepared.csv", index=False)
