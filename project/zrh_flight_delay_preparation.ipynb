# %%
import pandas as pd

# %% [markdown]
# # Data preparation
# ## Read and show Excel data for one day from Flightradar

# %%
# XLSX-Datei laden
flightradar = pd.read_excel("20250428_flightradar.xlsx")

# Erste 5 Zeilen anzeigen
print(flightradar.head(5))
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1745937263-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1745937263-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1745937263-3  https://www.flightradar24.com/data/airports/zr...   NaN
# 3      1745937263-4  https://www.flightradar24.com/data/airports/zr...   NaN
# 4      1745937263-5  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  FLIGHT  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   WK370
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  W22160
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00   GM600
# 3    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK134
# 4    NaN    NaN    NaN    NaN    NaN    NaN  06:00:00   WK348
#
#         DESTINATION           AIRLINE       AIRCRAFT          STATUS
# 0    Larnaca (LCA)-   Edelweiss Air -  A320 (HB-JJM)  Departed 06:02
# 1   Pristina (PRN)-      Flexflight -         320 ()         Unknown
# 2   Pristina (PRN)-  Chair Airlines -  A319 (HB-JOJ)  Departed 06:00
# 3   Hurghada (HRG)-   Edelweiss Air -  A320 (HB-IHZ)  Departed 06:11
# 4  Heraklion (HER)-   Edelweiss Air -  A320 (HB-JLR)  Departed 06:09

# %% [markdown]
# ## Show data types and shape of the DataFrame.

# %%
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# dtype: object
# (400, 15)

# %% [markdown]
# ## The Date is missing in the DataFrame. Create a new field DATETIME.
# ### DATETIME is the planned departure time for that day.

# %%
# Datum als Variable definieren
date_str = "2025-04-28"

# %%
# TIME als String sicherstellen (falls es z. B. float ist)
flightradar["TIME"] = flightradar["TIME"].astype(str)

# DATETIME-Feld erzeugen: 'date_str' + Zeit aus TIME-Feld
flightradar["DATETIME"] = date_str + " " + flightradar["TIME"]

# Kontrolle
print(flightradar[["TIME", "DATETIME"]].head())
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#        TIME             DATETIME
# 0  05:45:00  2025-04-28 05:45:00
# 1  05:45:00  2025-04-28 05:45:00
# 2  05:45:00  2025-04-28 05:45:00
# 3  06:00:00  2025-04-28 06:00:00
# 4  06:00:00  2025-04-28 06:00:00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# dtype: object
# (400, 16)

# %% [markdown]
# ## Create two new fields: DESTINATION_CLEAN and IATA_CODE using regex.

# %%
# DESTINATION_CLEAN: Alles vor der Klammer
flightradar["DESTINATION_CLEAN"] = flightradar["DESTINATION"].str.extract(r"^(.*?)\s*\(")

# IATA-CODE: Inhalt in der Klammer
flightradar["IATA_CODE"] = flightradar["DESTINATION"].str.extract(r"\((\w{3})\)")

# Kontrolle
print(flightradar[["DESTINATION", "DESTINATION_CLEAN", "IATA_CODE"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                  DESTINATION  DESTINATION_CLEAN IATA_CODE
# 0             Larnaca (LCA)-            Larnaca       LCA
# 1            Pristina (PRN)-           Pristina       PRN
# 2            Pristina (PRN)-           Pristina       PRN
# 3            Hurghada (HRG)-           Hurghada       HRG
# 4           Heraklion (HER)-          Heraklion       HER
# 5        Gran Canaria (LPA)-       Gran Canaria       LPA
# 6             Antalya (AYT)-            Antalya       AYT
# 7              Lisbon (LIS)-             Lisbon       LIS
# 8            Tenerife (TFS)-           Tenerife       TFS
# 9           Marrakesh (RAK)-          Marrakesh       RAK
# 10              Olbia (OLB)-              Olbia       OLB
# 11           Pristina (PRN)-           Pristina       PRN
# 12               Oslo (OSL)-               Oslo       OSL
# 13   Oberpfaffenhofen (OBF)-   Oberpfaffenhofen       OBF
# 14             Bilbao (BIO)-             Bilbao       BIO
# 15            Funchal (FNC)-            Funchal       FNC
# 16            Larnaca (LCA)-            Larnaca       LCA
# 17           Pristina (PRN)-           Pristina       PRN
# 18           Pristina (PRN)-           Pristina       PRN
# 19           Hurghada (HRG)-           Hurghada       HRG
# 20          Heraklion (HER)-          Heraklion       HER
# 21       Gran Canaria (LPA)-       Gran Canaria       LPA
# 22            Antalya (AYT)-            Antalya       AYT
# 23             Lisbon (LIS)-             Lisbon       LIS
# 24           Tenerife (TFS)-           Tenerife       TFS
# 25          Marrakesh (RAK)-          Marrakesh       RAK
# 26              Olbia (OLB)-              Olbia       OLB
# 27           Pristina (PRN)-           Pristina       PRN
# 28               Oslo (OSL)-               Oslo       OSL
# 29   Oberpfaffenhofen (OBF)-   Oberpfaffenhofen       OBF
# 30             Bilbao (BIO)-             Bilbao       BIO
# 31            Funchal (FNC)-            Funchal       FNC
# 32           Hurghada (HRG)-           Hurghada       HRG
# 33           Hurghada (HRG)-           Hurghada       HRG
# 34           Brindisi (BDS)-           Brindisi       BDS
# 35  Palma de Mallorca (PMI)-  Palma de Mallorca       PMI
# 36             London (LCY)-             London       LCY
# 37          Frankfurt (FRA)-          Frankfurt       FRA
# 38           Belgrade (BEG)-           Belgrade       BEG
# 39             Madrid (MAD)-             Madrid       MAD
# 40          Amsterdam (AMS)-          Amsterdam       AMS
# 41         Birmingham (BHX)-         Birmingham       BHX
# 42             Krakow (KRK)-             Krakow       KRK
# 43             London (LHR)-             London       LHR
# 44         Manchester (MAN)-         Manchester       MAN
# 45             Warsaw (WAW)-             Warsaw       WAW
# 46             Naples (NAP)-             Naples       NAP
# 47             London (LHR)-             London       LHR
# 48         Gothenburg (GOT)-         Gothenburg       GOT
# 49         Copenhagen (CPH)-         Copenhagen       CPH
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# dtype: object
# (400, 18)

# %% [markdown]
# ## Create three new fields: CANCELED, DEPART_TIME and DEPART_DATETIME using regex.

# %%
# 1. CANCELED-Spalte (Boolean)
flightradar["CANCELED"] = flightradar["STATUS"].str.contains("Canceled", na=False)

# 2. DEPART_TIME-Spalte (nur wenn "Departed HH:MM" enthalten ist)
flightradar["DEPART_TIME"] = flightradar["STATUS"].str.extract(r"Departed\s*(\d{2}:\d{2})")[0]

# 3. DEPART_DATETIME-Spalte: date_str + DEPART_TIME (fallback "00:00") + ":00"
flightradar["DEPART_DATETIME"] = (
    date_str
    + " "
    + flightradar["DEPART_TIME"].fillna("00:00") # falls keine Zeit da ist, setze "00:00"
    + ":00" # Sekunden anhängen
)

# Kontrolle
print(flightradar[["STATUS","CANCELED","DEPART_TIME","DEPART_DATETIME"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#
00
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# dtype: object
# (400, 21)

# %% [markdown]
# ## Creating the AIRLINE_CLEAN field and removing unimportant parts

# %%
flightradar["AIRLINE_CLEAN"] = (
    flightradar["AIRLINE"]
      .str.extract(r'^(.+?)(?=\s*(?:\(|-))')[0]  # Gruppe 1: alles bis vor "(" oder "-"
      .str.strip()                               # führende/trailing Leerzeichen entfernen
)

# Kontrolle
print(flightradar[["AIRLINE","AIRLINE_CLEAN"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#                                       AIRLINE     AIRLINE_CLEAN
# 0                             Edelweiss Air -     Edelweiss Air
# 1                                Flexflight -        Flexflight
# 2                            Chair Airlines -    Chair Airlines
# 3                             Edelweiss Air -     Edelweiss Air
# 4                             Edelweiss Air -     Edelweiss Air
# 5                             Edelweiss Air -     Edelweiss Air
# 6                             Edelweiss Air -     Edelweiss Air
# 7                          TAP Air Portugal -  TAP Air Portugal
# 8                             Edelweiss Air -     Edelweiss Air
# 9                             Edelweiss Air -     Edelweiss Air
# 10                            Edelweiss Air -     Edelweiss Air
# 11                            Edelweiss Air -     Edelweiss Air
# 12                           NetJets Europe -    NetJets Europe
# 13                           NetJets Europe -    NetJets Europe
# 14                            Edelweiss Air -     Edelweiss Air
# 15                            Edelweiss Air -     Edelweiss Air
# 16                            Edelweiss Air -     Edelweiss Air
# 17                               Flexflight -        Flexflight
# 18                           Chair Airlines -    Chair Airlines
# 19                            Edelweiss Air -     Edelweiss Air
# 20                            Edelweiss Air -     Edelweiss Air
# 21                            Edelweiss Air -     Edelweiss Air
# 22                            Edelweiss Air -     Edelweiss Air
# 23                         TAP Air Portugal -  TAP Air Portugal
# 24                            Edelweiss Air -     Edelweiss Air
# 25                            Edelweiss Air -     Edelweiss Air
# 26                            Edelweiss Air -     Edelweiss Air
# 27                            Edelweiss Air -     Edelweiss Air
# 28                           NetJets Europe -    NetJets Europe
# 29                           NetJets Europe -    NetJets Europe
# 30                            Edelweiss Air -     Edelweiss Air
# 31                            Edelweiss Air -     Edelweiss Air
# 32                               Flexflight -        Flexflight
# 33                           Chair Airlines -    Chair Airlines
# 34             Swiss (Star Alliance Livery) -             Swiss
# 35                                    Swiss -             Swiss
# 36                                    Swiss -             Swiss
# 37                         Helvetic Airways -  Helvetic Airways
# 38                                    Swiss -             Swiss
# 39                         Helvetic Airways -  Helvetic Airways
# 40                                      KLM -               KLM
# 41                         Helvetic Airways -  Helvetic Airways
# 42                               Air Baltic -        Air Baltic
# 43                                    Swiss -             Swiss
# 44                         Helvetic Airways -  Helvetic Airways
# 45                         Helvetic Airways -  Helvetic Airways
# 46                                    Swiss -             Swiss
# 47                                    Swiss -             Swiss
# 48  Helvetic Airways (1600th E-jet sticker) -  Helvetic Airways
# 49                         Helvetic Airways -  Helvetic Airways
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# dtype: object
# (400, 22)

# %% [markdown]
# ## Creating the AIRCRAFT_SHORT field

# %%
# Create the AIRCRAFT_SHORT field by removing text inside parentheses
flightradar["AIRCRAFT_SHORT"] = (
    flightradar["AIRCRAFT"]
      .str.replace(r"\s*\(.*?\)", "", regex=True)  # non‑greedy, regex=True
      .str.strip()
)

# Check the result
print(flightradar[["AIRCRAFT", "AIRCRAFT_SHORT"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
#          AIRCRAFT AIRCRAFT_SHORT
# 0   A320 (HB-JJM)           A320
# 1          320 ()            320
# 2   A319 (HB-JOJ)           A319
# 3   A320 (HB-IHZ)           A320
# 4   A320 (HB-JLR)           A320
# 5   A320 (HB-JJL)           A320
# 6   A320 (HB-JLS)           A320
# 7   A21N (CS-TJM)           A21N
# 8   A320 (HB-IJV)           A320
# 9   A320 (HB-IHX)           A320
# 10  A320 (HB-JJK)           A320
# 11  A359 (HB-IHF)           A359
# 12  E55P (CS-PJD)           E55P
# 13  C68A (CS-LTV)           C68A
# 14  A320 (HB-JLP)           A320
# 15  A320 (HB-IJW)           A320
# 16  A320 (HB-JJM)           A320
# 17         320 ()            320
# 18  A319 (HB-JOJ)           A319
# 19  A320 (HB-IHZ)           A320
# 20  A320 (HB-JLR)           A320
# 21  A320 (HB-JJL)           A320
# 22  A320 (HB-JLS)           A320
# 23  A21N (CS-TJM)           A21N
# 24  A320 (HB-IJV)           A320
# 25  A320 (HB-IHX)           A320
# 26  A320 (HB-JJK)           A320
# 27  A359 (HB-IHF)           A359
# 28  E55P (CS-PJD)           E55P
# 29  C68A (CS-LTV)           C68A
# 30  A320 (HB-JLP)           A320
# 31  A320 (HB-IJW)           A320
# 32         320 ()            320
# 33  A320 (HB-JOP)           A320
# 34  A320 (HB-IJM)           A320
# 35  A321 (HB-IOM)           A321
# 36  BCS1 (HB-JBH)           BCS1
# 37  E190 (HB-JVM)           E190
# 38  BCS3 (HB-JCA)           BCS3
# 39  E295 (HB-AZL)           E295
# 40  B739 (PH-BXR)           B739
# 41  E195 (HB-JVW)           E195
# 42  BCS3 (YL-AAW)           BCS3
# 43  A21N (HB-JPD)           A21N
# 44  E290 (HB-AZG)           E290
# 45  E295 (HB-AZK)           E295
# 46  A320 (HB-IJK)           A320
# 47  A21N (HB-JPD)           A21N
# 48  E290 (HB-AZE)           E290
# 49  E295 (HB-AZI)           E295
#
#
# web-scraper-order         object
# web-scraper-start-url     object
# page                     float64
# page2                    float64
# page3                    float64
# page4                    float64
# page5                    float64
# page6                    float64
# page7                    float64
# TIME                      object
# FLIGHT                    object
# DESTINATION               object
# AIRLINE                   object
# AIRCRAFT                  object
# STATUS                    object
# DATETIME                  object
# DESTINATION_CLEAN         object
# IATA_CODE                 object
# CANCELED                    bool
# DEPART_TIME               object
# DEPART_DATETIME           object
# AIRLINE_CLEAN             object
# AIRCRAFT_SHORT            object
# dtype: object
# (400, 23)

# %% [markdown]
# ## Create a new field DELAY and DELAY_MINUTES and calculate it from DATETIME and DEPART_DATETIME

# %%
# 1) Stelle sicher, dass beide Spalten als datetime64 vorliegen
flightradar["DATETIME"] = pd.to_datetime(flightradar["DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")
flightradar["DEPART_DATETIME"] = pd.to_datetime(flightradar["DEPART_DATETIME"], format="%Y-%m-%d %H:%M:%S", errors="coerce")

# 2) DELAY als Differenz berechnen
flightradar["DELAY"] = flightradar["DEPART_DATETIME"] - flightradar["DATETIME"]

# 3a) Variante A: Floor‑Division auf total_seconds, dann in int
flightradar["DELAY_MINUTES"] = (
    flightradar["DELAY"].dt.total_seconds() // 60
).astype(int)

# Kontrolle
print(flightradar[["DATETIME","DEPART_DATETIME","DELAY","DELAY_MINUTES"]].head(50))
print("\n")
print(flightradar.dtypes)
print(flightradar.shape)
# Out:
# 36 2025-04-28 06:55:00 2025-04-28 07:34:00   0 days 00:39:00             39
# 37 2025-04-28 06:55:00 2025-04-28 07:06:00   0 days 00:11:00             11
# 38 2025-04-28 06:55:00 2025-04-28 07:14:00   0 days 00:19:00             19
# 39 2025-04-28 06:55:00 2025-04-28 07:13:00   0 days 00:18:00             18
# 40 2025-04-28 07:00:00 2025-04-28 07:26:00   0 days 00:26:00             26
# 41 2025-04-28 07:00:00 2025-04-28 07:46:00   0 days 00:46:00             46
# 42 2025-04-28 07:00:00 2025-04-28 07:09:00   0 days 00:09:00              9
# 43 2025-04-28 07:05:00 2025-04-28 07:37:00   0 days 00:32:00             32
# 44 2025-04-28 07:05:00 2025-04-28 07:38:00   0 days 00:33:00             33
# 45 2025-04-28 07:05:00 2025-04-28 07:20:00   0 days 00:15:00             15
# 46 2025-04-28 07:05:00 2025-04-28 07:19:00   0 days 00:14:00             14
# 47 2025-04-28 07:05:00 2025-04-28 00:00:00 -1 days +16:55:00           -425
# 48 2025-04-28 07:10:00 2025-04-28 07:22:00   0 days 00:12:00             12
# 49 2025-04-28 07:10:00 2025-04-28 07:28:00   0 days 00:18:00             18
#
#
# web-scraper-order                 object
# web-scraper-start-url             object
# page                             float64
# page2                            float64
# page3                            float64
# page4                            float64
# page5                            float64
# page6                            float64
# page7                            float64
# TIME                              object
# FLIGHT                            object
# DESTINATION                       object
# AIRLINE                           object
# AIRCRAFT                          object
# STATUS                            object
# DATETIME                  datetime64[ns]
# DESTINATION_CLEAN                 object
# IATA_CODE                         object
# CANCELED                            bool
# DEPART_TIME                       object
# DEPART_DATETIME           datetime64[ns]
# AIRLINE_CLEAN                     object
# AIRCRAFT_SHORT                    object
# DELAY                    timedelta64[ns]
# DELAY_MINUTES                      int64
# dtype: object
# (400, 25)

# %% [markdown]
# ## Showing full DataFrame

# %%
flightradar.head(3)
# Out:
#   web-scraper-order                              web-scraper-start-url  page  \
# 0      1745937263-1  https://www.flightradar24.com/data/airports/zr...   NaN
# 1      1745937263-2  https://www.flightradar24.com/data/airports/zr...   NaN
# 2      1745937263-3  https://www.flightradar24.com/data/airports/zr...   NaN
#
#    page2  page3  page4  page5  page6  page7      TIME  ...  \
# 0    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 1    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
# 2    NaN    NaN    NaN    NaN    NaN    NaN  05:45:00  ...
#
#              DATETIME DESTINATION_CLEAN IATA_CODE CANCELED DEPART_TIME  \
# 0 2025-04-28 05:45:00           Larnaca       LCA    False       06:02
# 1 2025-04-28 05:45:00          Pristina       PRN    False         NaN
# 2 2025-04-28 05:45:00          Pristina       PRN    False       06:00
#
#       DEPART_DATETIME   AIRLINE_CLEAN AIRCRAFT_SHORT             DELAY  \
# 0 2025-04-28 06:02:00   Edelweiss Air           A320   0 days 00:17:00
# 1 2025-04-28 00:00:00      Flexflight            320 -1 days +18:15:00
# 2 2025-04-28 06:00:00  Chair Airlines           A319   0 days 00:15:00
#
#   DELAY_MINUTES
# 0            17
# 1          -345
# 2            15
#
# [3 rows x 25 columns]

# %% [markdown]
# ## Creating a New DataFrame with Selected Columns

# %%
# Create a new DataFrame with selected columns
flightradar_clean = flightradar[[
    "DESTINATION_CLEAN", 
    "IATA_CODE", 
    "AIRLINE_CLEAN", 
    "AIRCRAFT_SHORT", 
    "CANCELED", 
    "DATETIME",
    "DEPART_TIME", 
    "DEPART_DATETIME", 
    "DELAY_MINUTES"
]].copy()

# Check the result
print(flightradar_clean.head(50))
print("\n")
print(flightradar_clean.dtypes)
print(flightradar_clean.shape)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Larnaca       LCA     Edelweiss Air           A320     False
# 1            Pristina       PRN        Flexflight            320     False
# 2            Pristina       PRN    Chair Airlines           A319     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4           Heraklion       HER     Edelweiss Air           A320     False
# 5        Gran Canaria       LPA     Edelweiss Air           A320     False
# 6             Antalya       AYT     Edelweiss Air           A320     False
# 7              Lisbon       LIS  TAP Air Portugal           A21N     False
# 8            Tenerife       TFS     Edelweiss Air           A320     False
# 9           Marrakesh       RAK     Edelweiss Air           A320     False
# 10              Olbia       OLB     Edelweiss Air           A320     False
# 11           Pristina       PRN     Edelweiss Air           A359     False
# 12               Oslo       OSL    NetJets Europe           E55P     False
# 13   Oberpfaffenhofen       OBF    NetJets Europe           C68A     False
# 14             Bilbao       BIO     Edelweiss Air           A320     False
# 15            Funchal       FNC     Edelweiss Air           A320     False
# 16            Larnaca       LCA     Edelweiss Air           A320     False
# 17           Pristina       PRN        Flexflight            320     False
# 18           Pristina       PRN    Chair Airlines           A319     False
# 19           Hurghada       HRG     Edelweiss Air           A320     False
# 20          Heraklion       HER     Edelweiss Air           A320     False
# 21       Gran Canaria       LPA     Edelweiss Air           A320     False
# 22            Antalya       AYT     Edelweiss Air           A320     False
# 23             Lisbon       LIS  TAP Air Portugal           A21N     False
# 24           Tenerife       TFS     Edelweiss Air           A320     False
# 25          Marrakesh       RAK     Edelweiss Air           A320     False
# 26              Olbia       OLB     Edelweiss Air           A320     False
# 27           Pristina       PRN     Edelweiss Air           A359     False
# 28               Oslo       OSL    NetJets Europe           E55P     False
# 29   Oberpfaffenhofen       OBF    NetJets Europe           C68A     False
# 30             Bilbao       BIO     Edelweiss Air           A320     False
# 31            Funchal       FNC     Edelweiss Air           A320     False
# 32           Hurghada       HRG        Flexflight            320     False
# 33           Hurghada       HRG    Chair Airlines           A320     False
# 34           Brindisi       BDS             Swiss           A320     False
# 35  Palma de Mallorca       PMI             Swiss           A321     False
# 36             London       LCY             Swiss           BCS1     False
# 37          Frankfurt       FRA  Helvetic Airways           E190     False
# 38           Belgrade       BEG             Swiss           BCS3     False
# 39             Madrid       MAD  Helvetic Airways           E295     False
# 40          Amsterdam       AMS               KLM           B739     False
# 41         Birmingham       BHX  Helvetic Airways           E195     False
# 42             Krakow       KRK        Air Baltic           BCS3     False
# 43             London       LHR             Swiss           A21N     False
# 44         Manchester       MAN  Helvetic Airways           E290     False
# 45             Warsaw       WAW  Helvetic Airways           E295     False
# 46             Naples       NAP             Swiss           A320     False
# 47             London       LHR             Swiss           A21N     False
# 48         Gothenburg       GOT  Helvetic Airways           E290     False
# 49         Copenhagen       CPH  Helvetic Airways           E295     False
#
#               DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 
# 45 2025-04-28 07:05:00       07:20 2025-04-28 07:20:00             15
# 46 2025-04-28 07:05:00       07:19 2025-04-28 07:19:00             14
# 47 2025-04-28 07:05:00         NaN 2025-04-28 00:00:00           -425
# 48 2025-04-28 07:10:00       07:22 2025-04-28 07:22:00             12
# 49 2025-04-28 07:10:00       07:28 2025-04-28 07:28:00             18
#
#
# DESTINATION_CLEAN            object
# IATA_CODE                    object
# AIRLINE_CLEAN                object
# AIRCRAFT_SHORT               object
# CANCELED                       bool
# DATETIME             datetime64[ns]
# DEPART_TIME                  object
# DEPART_DATETIME      datetime64[ns]
# DELAY_MINUTES                 int64
# dtype: object
# (400, 9)

# %%
# Count missing values per column
print(flightradar_clean.isnull().sum())

# Total number of missing values in the DataFrame
print("Total missing values:", flightradar_clean.isnull().sum().sum())
# Out:
# DESTINATION_CLEAN     0
# IATA_CODE             0
# AIRLINE_CLEAN         5
# AIRCRAFT_SHORT        0
# CANCELED              0
# DATETIME              0
# DEPART_TIME          10
# DEPART_DATETIME       0
# DELAY_MINUTES         0
# dtype: int64
# Total missing values: 15

# %%
# Display columns with missing values
missing_values = flightradar_clean.isnull().sum()
missing_values = missing_values[missing_values > 0]

# Show the missing values
print("Columns with missing values:\n", missing_values)
# Out:
# Columns with missing values:
#  AIRLINE_CLEAN     5
# DEPART_TIME      10
# dtype: int64

# %%
# Filter rows with any missing values
missing_rows = flightradar_clean[flightradar_clean.isnull().any(axis=1)]

# Display rows with missing values
print(missing_rows)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 1            Pristina       PRN        Flexflight            320     False
# 17           Pristina       PRN        Flexflight            320     False
# 32           Hurghada       HRG        Flexflight            320     False
# 47             London       LHR             Swiss           A21N     False
# 82             Speyer       QCS               NaN           PA34     False
# 144             Genoa       GOA               NaN           CL60     False
# 209            Lisbon       LIS             Swiss           A21N     False
# 224            Lisbon       LIS  TAP Air Portugal           A20N      True
# 232            London       BQH               NaN           C25C     False
# 238            Munich       MUC               NaN           C525     False
# 265            Cannes       CEQ               NaN           SF50     False
# 324            Lisbon       LIS  TAP Air Portugal            32N      True
# 354            Lisbon       LIS             Swiss           A20N      True
# 372             Porto       OPO           easyJet            320      True
# 380            Malaga       AGP             Swiss           A20N      True
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 1   2025-04-28 05:45:00         NaN 2025-04-28 00:00:00           -345
# 17  2025-04-28 05:45:00         NaN 2025-04-28 00:00:00           -345
# 32  2025-04-28 06:45:00         NaN 2025-04-28 00:00:00           -405
# 47  2025-04-28 07:05:00         NaN 2025-04-28 00:00:00           -425
# 82  2025-04-28 08:15:00       08:30 2025-04-28 08:30:00             15
# 144 2025-04-28 10:55:00       11:04 2025-04-28 11:04:00              9
# 209 2025-04-28 12:50:00         NaN 2025-04-28 00:00:00           -770
# 224 2025-04-28 13:15:00         NaN 2025-04-28 00:00:00           -795
# 232 2025-04-28 13:30:00       14:11 2025-04-28 14:11:00             41
# 238 2025-04-28 14:15:00       14:21 2025-04-28 14:21:00              6
# 265 2025-04-28 16:25:00       16:35 2025-04-28 16:35:00             10
# 324 2025-04-28 18:05:00         NaN 2025-04-28 00:00:00          -1085
# 354 2025-04-28 20:05:00         NaN 2025-04-28 00:00:00          -1205
# 372 2025-04-28 21:10:00         NaN 2025-04-28 00:00:00          -1270
# 380 2025-04-28 21:30:00         NaN 2025-04-28 00:00:00          -1290

# %%
# Drop rows with any missing values (NaN)
flightradar_clean = flightradar_clean.dropna(axis=0)

# Display the DataFrame after dropping rows with missing values
print(flightradar_clean)
# Out:
#     DESTINATION_CLEAN IATA_CODE     AIRLINE_CLEAN AIRCRAFT_SHORT  CANCELED  \
# 0             Larnaca       LCA     Edelweiss Air           A320     False
# 2            Pristina       PRN    Chair Airlines           A319     False
# 3            Hurghada       HRG     Edelweiss Air           A320     False
# 4           Heraklion       HER     Edelweiss Air           A320     False
# 5        Gran Canaria       LPA     Edelweiss Air           A320     False
# ..                ...       ...               ...            ...       ...
# 395         Hong Kong       HKG             Swiss           B77W     False
# 396         Singapore       SIN             Swiss           B77W     False
# 397      Johannesburg       JNB             Swiss           A343     False
# 398             Milan       MXP  Helvetic Airways           E190     False
# 399            Geneva       GVA             Swiss           BCS1     False
#
#                DATETIME DEPART_TIME     DEPART_DATETIME  DELAY_MINUTES
# 0   2025-04-28 05:45:00       06:02 2025-04-28 06:02:00             17
# 2   2025-04-28 05:45:00       06:00 2025-04-28 06:00:00             15
# 3   2025-04-28 06:00:00       06:11 2025-04-28 06:11:00             11
# 4   2025-04-28 06:00:00       06:09 2025-04-28 06:09:00              9
# 5   2025-04-28 06:10:00       06:40 2025-04-28 06:40:00             30
# ..                  ...         ...                 ...            ...
# 395 2025-04-28 22:40:00       22:53 2025-04-28 22:53:00             13
# 396 2025-04-28 22:40:00       23:02 2025-04-28 23:02:00             22
# 397 2025-04-28 22:40:00       22:50 2025-04-28 22:50:00             10
# 398 2025-04-28 22:40:00       22:59 2025-04-28 22:59:00             19
# 399 2025-04-28 22:45:00       23:05 2025-04-28 23:05:00             20
#
# [385 rows x 9 columns]

# %% [markdown]
# # WETTER DATEN

# %%
# CSV‑Datei laden (im gleichen Verzeichnis wie dein Notebook)
weather = pd.read_csv("weather.csv")

# Erstmal Überblick verschaffen
print(weather.head())        # erste 5 Zeilen
print(weather.dtypes)        # Datentypen der Spalten
print(weather.shape)         # (Anzahl Zeilen, Anzahl Spalten)
# Out:
#                   time  temp  dwpt  rhum  prcp  snow  wdir  wspd  wpgt  \
# 0  2025-04-28 00:00:00   9.9   8.3    90     0   NaN   293     2  15.0
# 1  2025-04-28 01:00:00   8.4   8.0    97     0   NaN   276     5   9.0
# 2  2025-04-28 02:00:00   8.2   7.8    97     0   NaN   283     7  13.0
# 3  2025-04-28 03:00:00   7.8   7.0    95     0   NaN   304     3   7.0
# 4  2025-04-28 04:00:00   5.8   5.5    98     0   NaN   306     4   6.0
#
#      pres  tsun  coco
# 0  1024.8   NaN     2
# 1  1025.0   NaN     2
# 2  1024.8   NaN     2
# 3  1024.7   NaN     5
# 4  1025.1   NaN     5
# time     object
# temp    float64
# dwpt    float64
# rhum      int64
# prcp      int64
# snow    float64
# wdir      int64
# wspd      int64
# wpgt    float64
# pres    float64
# tsun    float64
# coco      int64
# dtype: object
# (96, 12)
